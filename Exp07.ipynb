# %%
! python train.py \
    --dataroot /root/autodl-tmp/train_data/AUGAN_DATA_Nii \
    --name run_Final_D512_BS8_HighLR_smalldata \
    --model augan \
    --netG unet_3d \
    --batch_size 8 \
    --patch_size_d 512 \
    --patch_size_h 128 \
    --patch_size_w 128 \
    --pixel_loss L1 \
    --lambda_pixel 100.0 \
    --norm batch \
    --lr 0.0004 \
    --lr_d_ratio 0.1 \
    --spacing_z 0.0362 \
    --spacing_x 0.2 \
    --no_flip \
    --no_elastic \
    --gpu_ids 0 \
    --checkpoints_dir /root/AUGAN_3D_Recon/checkpoints \
    --num_workers 8 \
    # --continue_train \
    # --epoch_count 75
# Out:
# ⚖️  Detecting Class Imbalance... Calculating weights.
# ✅  WeightedRandomSampler activated. (Shuffle set to False automatically)
# Dataset [UltrasoundDataset] created. Size: 610, Batch Size: 8, Shuffle: False, Sampler: Active, Workers: 8
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 2]
#                     beta1: 0.5
#           checkpoints_dir: /root/AUGAN_3D_Recon/checkpoints	[default: ./checkpoints]
#            continue_train: False
#                  dataroot: /root/autodl-tmp/train_data/AUGAN_DATA_Nii	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#              lambda_pixel: 100.0
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0004                        	[default: 0.0002]
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: run_Final_D512_BS8_HighLR_smalldata	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 8                             	[default: 4]
#                 output_nc: 1
#              patch_size_d: 512                           	[default: 256]
#              patch_size_h: 128                           	[default: 64]
#              patch_size_w: 128                           	[default: 64]
#                     phase: train
#                pixel_loss: L1
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /root/autodl-tmp/train_data/AUGAN_DATA_Nii
#   - Dataset Size:  76 volumes
#   - Batch Size:    8
#   - Patch Size:    [D=512, H=128, W=128]
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0004, D=4e-05
#   - Pixel Loss:    L1 (Weight: 100.0)
#   - Augmentation:  No Flip, No Elastic
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 1 / 200
# Epoch 1:   0%|                                        | 0/76 [00:00<?, ?batch/s]/root/AUGAN_3D_Recon/models/base_model.py:104: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 1: 100%|████████████| 76/76 [12:57<00:00, 10.22s/batch, pixel_loss=18.262]
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 777 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.9171
#       ├─ G_Adversarial: 	 0.9171
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.9012
#       ├─ D_Real_Loss: 	 0.9274
#       └─ D_Fake_Loss: 	 0.8750
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 1 Visual Saved: epoch_001.png
#   📦 NIfTI Saved: epoch_001_fake.nii.gz
#
# Start Epoch 2 / 200
# Epoch 2: 100%|████████████| 76/76 [12:57<00:00, 10.23s/batch, pixel_loss=17.298]
# --------------------------------------------------------------------------------
# END OF EPOCH 2 / 200 	 Time Taken: 777 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.8678
#       ├─ G_Adversarial: 	 0.8678
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6815
#       ├─ D_Real_Loss: 	 0.6896
#       └─ D_Fake_Loss: 	 0.6735
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 2 Visual Saved: epoch_002.png
#   📦 NIfTI Saved: epoch_002_fake.nii.gz
#
# Start Epoch 3 / 200
# Epoch 3: 100%|████████████| 76/76 [12:56<00:00, 10.22s/batch, pixel_loss=16.807]
# --------------------------------------------------------------------------------
# END OF EPOCH 3 / 200 	 Time Taken: 777 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1517
#       ├─ G_Adversarial: 	 1.1517
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5736
#       ├─ D_Real_Loss: 	 0.5750
#       └─ D_Fake_Loss: 	 0.5723
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 3 Visual Saved: epoch_003.png
#   📦 NIfTI Saved: epoch_003_fake.nii.gz
#
# Start Epoch 4 / 200
# Epoch 4: 100%|████████████| 76/76 [12:54<00:00, 10.20s/batch, pixel_loss=17.822]
# --------------------------------------------------------------------------------
# END OF EPOCH 4 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.2768
#       ├─ G_Adversarial: 	 1.2768
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5640
#       ├─ D_Real_Loss: 	 0.5633
#       └─ D_Fake_Loss: 	 0.5647
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 4 Visual Saved: epoch_004.png
#   📦 NIfTI Saved: epoch_004_fake.nii.gz
#
# Start Epoch 5 / 200
# Epoch 5: 100%|████████████| 76/76 [12:54<00:00, 10.20s/batch, pixel_loss=18.025]
# --------------------------------------------------------------------------------
# END OF EPOCH 5 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.3488
#       ├─ G_Adversarial: 	 1.3488
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5475
#       ├─ D_Real_Loss: 	 0.5492
#       └─ D_Fake_Loss: 	 0.5458
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 5 Visual Saved: epoch_005.png
#   📦 NIfTI Saved: epoch_005_fake.nii.gz
# 💾 Saving checkpoints at epoch 5
#
# Start Epoch 6 / 200
# Epoch 6: 100%|████████████| 76/76 [12:54<00:00, 10.19s/batch, pixel_loss=17.004]
# --------------------------------------------------------------------------------
# END OF EPOCH 6 / 200 	 Time Taken: 774 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.3513
#       ├─ G_Adversarial: 	 1.3513
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5464
#       ├─ D_Real_Loss: 	 0.5470
#       └─ D_Fake_Loss: 	 0.5457
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 6 Visual Saved: epoch_006.png
#   📦 NIfTI Saved: epoch_006_fake.nii.gz
#
# Start Epoch 7 / 200
# Epoch 7: 100%|████████████| 76/76 [12:54<00:00, 10.19s/batch, pixel_loss=17.354]
# --------------------------------------------------------------------------------
# END OF EPOCH 7 / 200 	 Time Taken: 774 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.3171
#       ├─ G_Adversarial: 	 1.3171
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5543
#       ├─ D_Real_Loss: 	 0.5505
#       └─ D_Fake_Loss: 	 0.5582
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 7 Visual Saved: epoch_007.png
#   📦 NIfTI Saved: epoch_007_fake.nii.gz
#
# Start Epoch 8 / 200
# Epoch 8: 100%|████████████| 76/76 [12:55<00:00, 10.21s/batch, pixel_loss=18.098]
# --------------------------------------------------------------------------------
# END OF EPOCH 8 / 200 	 Time Taken: 776 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.2862
#       ├─ G_Adversarial: 	 1.2862
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5641
#       ├─ D_Real_Loss: 	 0.5632
#       └─ D_Fake_Loss: 	 0.5651
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 8 Visual Saved: epoch_008.png
#   📦 NIfTI Saved: epoch_008_fake.nii.gz
#
# Start Epoch 9 / 200
# Epoch 9: 100%|████████████| 76/76 [12:54<00:00, 10.19s/batch, pixel_loss=19.768]
# --------------------------------------------------------------------------------
# END OF EPOCH 9 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.2556
#       ├─ G_Adversarial: 	 1.2556
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5793
#       ├─ D_Real_Loss: 	 0.5783
#       └─ D_Fake_Loss: 	 0.5803
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 9 Visual Saved: epoch_009.png
#   📦 NIfTI Saved: epoch_009_fake.nii.gz
#
# Start Epoch 10 / 200
# Epoch 10: 100%|███████████| 76/76 [12:54<00:00, 10.20s/batch, pixel_loss=18.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 10 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.2242
#       ├─ G_Adversarial: 	 1.2242
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5809
#       ├─ D_Real_Loss: 	 0.5802
#       └─ D_Fake_Loss: 	 0.5816
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 10 Visual Saved: epoch_010.png
#   📦 NIfTI Saved: epoch_010_fake.nii.gz
# 💾 Saving checkpoints at epoch 10
#
# Start Epoch 11 / 200
# Epoch 11: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=16.197]
# --------------------------------------------------------------------------------
# END OF EPOCH 11 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.2041
#       ├─ G_Adversarial: 	 1.2041
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5952
#       ├─ D_Real_Loss: 	 0.5912
#       └─ D_Fake_Loss: 	 0.5993
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 11 Visual Saved: epoch_011.png
#   📦 NIfTI Saved: epoch_011_fake.nii.gz
#
# Start Epoch 12 / 200
# Epoch 12: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.462]
# --------------------------------------------------------------------------------
# END OF EPOCH 12 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1433
#       ├─ G_Adversarial: 	 1.1433
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6026
#       ├─ D_Real_Loss: 	 0.6077
#       └─ D_Fake_Loss: 	 0.5976
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 12 Visual Saved: epoch_012.png
#   📦 NIfTI Saved: epoch_012_fake.nii.gz
#
# Start Epoch 13 / 200
# Epoch 13: 100%|███████████| 76/76 [12:54<00:00, 10.20s/batch, pixel_loss=18.290]
# --------------------------------------------------------------------------------
# END OF EPOCH 13 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1055
#       ├─ G_Adversarial: 	 1.1055
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6121
#       ├─ D_Real_Loss: 	 0.6067
#       └─ D_Fake_Loss: 	 0.6175
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 13 Visual Saved: epoch_013.png
#   📦 NIfTI Saved: epoch_013_fake.nii.gz
#
# Start Epoch 14 / 200
# Epoch 14: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.441]
# --------------------------------------------------------------------------------
# END OF EPOCH 14 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1091
#       ├─ G_Adversarial: 	 1.1091
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6186
#       ├─ D_Real_Loss: 	 0.6201
#       └─ D_Fake_Loss: 	 0.6172
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 14 Visual Saved: epoch_014.png
#   📦 NIfTI Saved: epoch_014_fake.nii.gz
#
# Start Epoch 15 / 200
# Epoch 15: 100%|███████████| 76/76 [12:54<00:00, 10.19s/batch, pixel_loss=16.286]
# --------------------------------------------------------------------------------
# END OF EPOCH 15 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0811
#       ├─ G_Adversarial: 	 1.0811
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6241
#       ├─ D_Real_Loss: 	 0.6235
#       └─ D_Fake_Loss: 	 0.6246
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 15 Visual Saved: epoch_015.png
#   📦 NIfTI Saved: epoch_015_fake.nii.gz
# 💾 Saving checkpoints at epoch 15
#
# Start Epoch 16 / 200
# Epoch 16: 100%|███████████| 76/76 [12:54<00:00, 10.19s/batch, pixel_loss=19.472]
# --------------------------------------------------------------------------------
# END OF EPOCH 16 / 200 	 Time Taken: 774 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0662
#       ├─ G_Adversarial: 	 1.0662
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6179
#       ├─ D_Real_Loss: 	 0.6217
#       └─ D_Fake_Loss: 	 0.6141
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 16 Visual Saved: epoch_016.png
#   📦 NIfTI Saved: epoch_016_fake.nii.gz
#
# Start Epoch 17 / 200
# Epoch 17: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=16.748]
# --------------------------------------------------------------------------------
# END OF EPOCH 17 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0844
#       ├─ G_Adversarial: 	 1.0844
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6317
#       ├─ D_Real_Loss: 	 0.6313
#       └─ D_Fake_Loss: 	 0.6322
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 17 Visual Saved: epoch_017.png
#   📦 NIfTI Saved: epoch_017_fake.nii.gz
#
# Start Epoch 18 / 200
# Epoch 18: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.801]
# --------------------------------------------------------------------------------
# END OF EPOCH 18 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0822
#       ├─ G_Adversarial: 	 1.0822
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6178
#       ├─ D_Real_Loss: 	 0.6197
#       └─ D_Fake_Loss: 	 0.6158
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 18 Visual Saved: epoch_018.png
#   📦 NIfTI Saved: epoch_018_fake.nii.gz
#
# Start Epoch 19 / 200
# Epoch 19: 100%|███████████| 76/76 [12:53<00:00, 10.18s/batch, pixel_loss=18.735]
# --------------------------------------------------------------------------------
# END OF EPOCH 19 / 200 	 Time Taken: 774 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0694
#       ├─ G_Adversarial: 	 1.0694
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6181
#       ├─ D_Real_Loss: 	 0.6161
#       └─ D_Fake_Loss: 	 0.6200
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 19 Visual Saved: epoch_019.png
#   📦 NIfTI Saved: epoch_019_fake.nii.gz
#
# Start Epoch 20 / 200
# Epoch 20: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=18.406]
# --------------------------------------------------------------------------------
# END OF EPOCH 20 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0534
#       ├─ G_Adversarial: 	 1.0534
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6215
#       ├─ D_Real_Loss: 	 0.6206
#       └─ D_Fake_Loss: 	 0.6225
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 20 Visual Saved: epoch_020.png
#   📦 NIfTI Saved: epoch_020_fake.nii.gz
# 💾 Saving checkpoints at epoch 20
#
# Start Epoch 21 / 200
# Epoch 21: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.324]
# --------------------------------------------------------------------------------
# END OF EPOCH 21 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0804
#       ├─ G_Adversarial: 	 1.0804
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6301
#       ├─ D_Real_Loss: 	 0.6269
#       └─ D_Fake_Loss: 	 0.6333
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 21 Visual Saved: epoch_021.png
#   📦 NIfTI Saved: epoch_021_fake.nii.gz
#
# Start Epoch 22 / 200
# Epoch 22: 100%|███████████| 76/76 [12:55<00:00, 10.21s/batch, pixel_loss=17.535]
# --------------------------------------------------------------------------------
# END OF EPOCH 22 / 200 	 Time Taken: 776 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0661
#       ├─ G_Adversarial: 	 1.0661
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6222
#       ├─ D_Real_Loss: 	 0.6214
#       └─ D_Fake_Loss: 	 0.6230
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 22 Visual Saved: epoch_022.png
#   📦 NIfTI Saved: epoch_022_fake.nii.gz
#
# Start Epoch 23 / 200
# Epoch 23: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.353]
# --------------------------------------------------------------------------------
# END OF EPOCH 23 / 200 	 Time Taken: 775 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1333
#       ├─ G_Adversarial: 	 1.1333
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6057
#       ├─ D_Real_Loss: 	 0.6038
#       └─ D_Fake_Loss: 	 0.6075
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 23 Visual Saved: epoch_023.png
#   📦 NIfTI Saved: epoch_023_fake.nii.gz
#
# Start Epoch 24 / 200
# Epoch 24: 100%|███████████| 76/76 [12:55<00:00, 10.20s/batch, pixel_loss=17.911]
# --------------------------------------------------------------------------------
# END OF EPOCH 24 / 200 	 Time Taken: 776 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1014
#       ├─ G_Adversarial: 	 1.1014
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6121
#       ├─ D_Real_Loss: 	 0.6103
#       └─ D_Fake_Loss: 	 0.6138
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 24 Visual Saved: epoch_024.png
#   📦 NIfTI Saved: epoch_024_fake.nii.gz
#
# Start Epoch 25 / 200
# Epoch 25: 100%|███████████| 76/76 [12:56<00:00, 10.21s/batch, pixel_loss=20.283]
# --------------------------------------------------------------------------------
# END OF EPOCH 25 / 200 	 Time Taken: 776 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0882
#       ├─ G_Adversarial: 	 1.0882
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6231
#       ├─ D_Real_Loss: 	 0.6278
#       └─ D_Fake_Loss: 	 0.6184
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 25 Visual Saved: epoch_025.png
#   📦 NIfTI Saved: epoch_025_fake.nii.gz
# 💾 Saving checkpoints at epoch 25
#
# Start Epoch 26 / 200
# Epoch 26:  26%|██▉        | 20/76 [03:26<09:27, 10.14s/batch, pixel_loss=17.949]^C

# %%
! python train.py \
    --dataroot /root/autodl-tmp/train_data/AUGAN_DATA_Nii \
    --name run_Final_D512_BS8_HighLR_smalldata_Trilinear \
    --model augan \
    --netG unet_3d \
    --batch_size 8 \
    --patch_size_d 512 \
    --patch_size_h 128 \
    --patch_size_w 128 \
    --pixel_loss L1 \
    --lambda_pixel 100.0 \
    --norm batch \
    --lr 0.0004 \
    --lr_d_ratio 0.1 \
    --spacing_z 0.0362 \
    --spacing_x 0.2 \
    --no_flip \
    --no_elastic \
    --gpu_ids 0 \
    --checkpoints_dir /root/autodl-tmp/checkpoints \
    --num_workers 8 \
    --continue_train \
    --epoch_count 90
# Out:
# ⚖️  Detecting Class Imbalance... Calculating weights.
# ✅  WeightedRandomSampler activated. (Shuffle set to False automatically)
# Dataset [UltrasoundDataset] created. Size: 712, Batch Size: 8, Shuffle: False, Sampler: Active, Workers: 8
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# loading the model from /root/AUGAN_3D_Recon/checkpoints/run_Final_D512_BS8_HighLR_smalldata/latest_net_G.pth
# loading the model from /root/AUGAN_3D_Recon/checkpoints/run_Final_D512_BS8_HighLR_smalldata/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 2]
#                     beta1: 0.5
#           checkpoints_dir: /root/AUGAN_3D_Recon/checkpoints	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  dataroot: /root/autodl-tmp/train_data/AUGAN_DATA_Nii	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#                     epoch: latest
#               epoch_count: 90                            	[default: 1]
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#              lambda_pixel: 100.0
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0004                        	[default: 0.0002]
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: run_Final_D512_BS8_HighLR_smalldata	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 8                             	[default: 4]
#                 output_nc: 1
#              patch_size_d: 512                           	[default: 256]
#              patch_size_h: 128                           	[default: 64]
#              patch_size_w: 128                           	[default: 64]
#                     phase: train
#                pixel_loss: L1
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /root/autodl-tmp/train_data/AUGAN_DATA_Nii
#   - Dataset Size:  89 volumes
#   - Batch Size:    8
#   - Patch Size:    [D=512, H=128, W=128]
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0004, D=4e-05
#   - Pixel Loss:    L1 (Weight: 100.0)
#   - Augmentation:  No Flip, No Elastic
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 90 / 200
# Epoch 90:   0%|                                       | 0/89 [00:00<?, ?batch/s]/root/AUGAN_3D_Recon/models/base_model.py:104: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 90: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=16.780]
# --------------------------------------------------------------------------------
# END OF EPOCH 90 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0533
#       ├─ G_Adversarial: 	 1.0533
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6234
#       ├─ D_Real_Loss: 	 0.6269
#       └─ D_Fake_Loss: 	 0.6199
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 90 Visual Saved: epoch_090.png
#   📦 NIfTI Saved: epoch_090_fake.nii.gz
# 💾 Saving checkpoints at epoch 90
#
# Start Epoch 91 / 200
# Epoch 91: 100%|███████████| 89/89 [15:08<00:00, 10.21s/batch, pixel_loss=13.719]
# --------------------------------------------------------------------------------
# END OF EPOCH 91 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0217
#       ├─ G_Adversarial: 	 1.0217
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6268
#       ├─ D_Real_Loss: 	 0.6214
#       └─ D_Fake_Loss: 	 0.6323
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 91 Visual Saved: epoch_091.png
#   📦 NIfTI Saved: epoch_091_fake.nii.gz
#
# Start Epoch 92 / 200
# Epoch 92: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=16.640]
# --------------------------------------------------------------------------------
# END OF EPOCH 92 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0532
#       ├─ G_Adversarial: 	 1.0532
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6290
#       ├─ D_Real_Loss: 	 0.6245
#       └─ D_Fake_Loss: 	 0.6335
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 92 Visual Saved: epoch_092.png
#   📦 NIfTI Saved: epoch_092_fake.nii.gz
#
# Start Epoch 93 / 200
# Epoch 93: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=14.363]
# --------------------------------------------------------------------------------
# END OF EPOCH 93 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0250
#       ├─ G_Adversarial: 	 1.0250
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6256
#       ├─ D_Real_Loss: 	 0.6229
#       └─ D_Fake_Loss: 	 0.6283
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 93 Visual Saved: epoch_093.png
#   📦 NIfTI Saved: epoch_093_fake.nii.gz
#
# Start Epoch 94 / 200
# Epoch 94: 100%|███████████| 89/89 [15:10<00:00, 10.23s/batch, pixel_loss=13.277]
# --------------------------------------------------------------------------------
# END OF EPOCH 94 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0347
#       ├─ G_Adversarial: 	 1.0347
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6294
#       ├─ D_Real_Loss: 	 0.6264
#       └─ D_Fake_Loss: 	 0.6323
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 94 Visual Saved: epoch_094.png
#   📦 NIfTI Saved: epoch_094_fake.nii.gz
#
# Start Epoch 95 / 200
# Epoch 95: 100%|███████████| 89/89 [15:10<00:00, 10.23s/batch, pixel_loss=13.774]
# --------------------------------------------------------------------------------
# END OF EPOCH 95 / 200 	 Time Taken: 911 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0668
#       ├─ G_Adversarial: 	 1.0668
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6074
#       ├─ D_Real_Loss: 	 0.6054
#       └─ D_Fake_Loss: 	 0.6094
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 95 Visual Saved: epoch_095.png
#   📦 NIfTI Saved: epoch_095_fake.nii.gz
# 💾 Saving checkpoints at epoch 95
#
# Start Epoch 96 / 200
# Epoch 96: 100%|███████████| 89/89 [15:08<00:00, 10.21s/batch, pixel_loss=12.233]
# --------------------------------------------------------------------------------
# END OF EPOCH 96 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0299
#       ├─ G_Adversarial: 	 1.0299
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6228
#       ├─ D_Real_Loss: 	 0.6227
#       └─ D_Fake_Loss: 	 0.6230
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 96 Visual Saved: epoch_096.png
#   📦 NIfTI Saved: epoch_096_fake.nii.gz
#
# Start Epoch 97 / 200
# Epoch 97: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=17.457]
# --------------------------------------------------------------------------------
# END OF EPOCH 97 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0406
#       ├─ G_Adversarial: 	 1.0406
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6316
#       ├─ D_Real_Loss: 	 0.6330
#       └─ D_Fake_Loss: 	 0.6303
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 97 Visual Saved: epoch_097.png
#   📦 NIfTI Saved: epoch_097_fake.nii.gz
#
# Start Epoch 98 / 200
# Epoch 98: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=16.596]
# --------------------------------------------------------------------------------
# END OF EPOCH 98 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1723
#       ├─ G_Adversarial: 	 1.1723
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.5896
#       ├─ D_Real_Loss: 	 0.5871
#       └─ D_Fake_Loss: 	 0.5921
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 98 Visual Saved: epoch_098.png
#   📦 NIfTI Saved: epoch_098_fake.nii.gz
#
# Start Epoch 99 / 200
# Epoch 99: 100%|███████████| 89/89 [15:10<00:00, 10.23s/batch, pixel_loss=16.022]
# --------------------------------------------------------------------------------
# END OF EPOCH 99 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1135
#       ├─ G_Adversarial: 	 1.1135
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6179
#       ├─ D_Real_Loss: 	 0.6182
#       └─ D_Fake_Loss: 	 0.6175
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 99 Visual Saved: epoch_099.png
#   📦 NIfTI Saved: epoch_099_fake.nii.gz
#
# Start Epoch 100 / 200
# Epoch 100: 100%|██████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=17.749]
# --------------------------------------------------------------------------------
# END OF EPOCH 100 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0772
#       ├─ G_Adversarial: 	 1.0772
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6253
#       ├─ D_Real_Loss: 	 0.6260
#       └─ D_Fake_Loss: 	 0.6245
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 100 Visual Saved: epoch_100.png
#   📦 NIfTI Saved: epoch_100_fake.nii.gz
# 💾 Saving checkpoints at epoch 100
#
# Start Epoch 101 / 200
# Epoch 101: 100%|██████████| 89/89 [15:09<00:00, 10.21s/batch, pixel_loss=15.279]
# --------------------------------------------------------------------------------
# END OF EPOCH 101 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0003960 | D_lr = 0.0000396
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0847
#       ├─ G_Adversarial: 	 1.0847
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6149
#       ├─ D_Real_Loss: 	 0.6110
#       └─ D_Fake_Loss: 	 0.6187
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 101 Visual Saved: epoch_101.png
#   📦 NIfTI Saved: epoch_101_fake.nii.gz
#
# Start Epoch 102 / 200
# Epoch 102: 100%|██████████| 89/89 [15:10<00:00, 10.23s/batch, pixel_loss=12.835]
# --------------------------------------------------------------------------------
# END OF EPOCH 102 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0003921 | D_lr = 0.0000392
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.1076
#       ├─ G_Adversarial: 	 1.1076
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6267
#       ├─ D_Real_Loss: 	 0.6283
#       └─ D_Fake_Loss: 	 0.6250
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 102 Visual Saved: epoch_102.png
#   📦 NIfTI Saved: epoch_102_fake.nii.gz
#
# Start Epoch 103 / 200
# Epoch 103: 100%|██████████| 89/89 [15:10<00:00, 10.23s/batch, pixel_loss=16.241]
# --------------------------------------------------------------------------------
# END OF EPOCH 103 / 200 	 Time Taken: 910 sec
#   Learning Rates: 	 G_lr = 0.0003881 | D_lr = 0.0000388
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0628
#       ├─ G_Adversarial: 	 1.0628
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6202
#       ├─ D_Real_Loss: 	 0.6181
#       └─ D_Fake_Loss: 	 0.6223
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 103 Visual Saved: epoch_103.png
#   📦 NIfTI Saved: epoch_103_fake.nii.gz
#
# Start Epoch 104 / 200
# Epoch 104: 100%|███████████| 89/89 [15:09<00:00, 10.22s/batch, pixel_loss=8.767]
# --------------------------------------------------------------------------------
# END OF EPOCH 104 / 200 	 Time Taken: 909 sec
#   Learning Rates: 	 G_lr = 0.0003842 | D_lr = 0.0000384
#   Average Losses:
#     Generator (G): 	 Total ≈ 1.0873
#       ├─ G_Adversarial: 	 1.0873
#       └─ G_Pixelwise: 	 0.0000
#     Discriminator (D): 	 Total ≈ 0.6208
#       ├─ D_Real_Loss: 	 0.6155
#       └─ D_Fake_Loss: 	 0.6261
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 104 Visual Saved: epoch_104.png
#   📦 NIfTI Saved: epoch_104_fake.nii.gz
#
# Start Epoch 105 / 200
# Epoch 105:  36%|███▌      | 32/89 [05:29<09:39, 10.17s/batch, pixel_loss=13.828]^C

# %%
! python train.py \
    --dataroot /root/autodl-tmp/train_data/AUGAN_DATA_Nii \
    --name run_Final_D256_BS10_HighLR_smalldata_Trilinear \
    --model augan \
    --netG unet_3d \
    --batch_size 8 \
    --patch_size_d 256 \
    --patch_size_h 128 \
    --patch_size_w 128 \
    --pixel_loss L1 \
    --lambda_pixel 100.0 \
    --norm batch \
    --lr 0.0004 \
    --lr_d_ratio 0.1 \
    --spacing_z 0.0362 \
    --spacing_x 0.2 \
    --no_flip \
    --no_elastic \
    --gpu_ids 0 \
    --checkpoints_dir /root/autodl-tmp/checkpoints \
    --num_workers 8
# Out:
# ⚖️  Detecting Class Imbalance... Calculating weights.
# ✅  WeightedRandomSampler activated. (Shuffle set to False automatically)
# Dataset [UltrasoundDataset] created. Size: 712, Batch Size: 10, Shuffle: False, Sampler: Active, Workers: 8
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 91.687 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 10                            	[default: 2]
#                     beta1: 0.5
#           checkpoints_dir: /root/autodl-tmp/checkpoints  	[default: ./checkpoints]
#            continue_train: False
#                  dataroot: /root/autodl-tmp/train_data/AUGAN_DATA_Nii	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#              lambda_pixel: 100.0
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0004                        	[default: 0.0002]
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: run_Final_D256_BS10_HighLR_smalldata_Trilinear	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 8                             	[default: 4]
#                 output_nc: 1
#              patch_size_d: 256
#              patch_size_h: 128                           	[default: 64]
#              patch_size_w: 128                           	[default: 64]
#                     phase: train
#                pixel_loss: L1
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /root/autodl-tmp/train_data/AUGAN_DATA_Nii
#   - Dataset Size:  71 volumes
#   - Batch Size:    10
#   - Patch Size:    [D=256, H=128, W=128]
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0004, D=4e-05
#   - Pixel Loss:    L1 (Weight: 100.0)
#   - Augmentation:  No Flip, No Elastic
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 1 / 200
# Epoch 1:   0%|                                        | 0/71 [00:02<?, ?batch/s]
# Traceback (most recent call last):
#   File "/root/AUGAN_3D_Recon/train.py", line 187, in <module>
#     model.optimize_parameters()
#   File "/root/AUGAN_3D_Recon/models/augan_model.py", line 141, in optimize_parameters
#     self.forward()                   # 计算 G(A)
#   File "/root/AUGAN_3D_Recon/models/augan_model.py", line 102, in forward
#     self.fake_hq = self.netG(self.real_lq)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/AUGAN_3D_Recon/models/networks/generator.py", line 54, in forward
#     return self.model(input)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/AUGAN_3D_Recon/models/networks/generator.py", line 233, in forward
#     return self.model(x)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/container.py", line 253, in forward
#     input = module(input)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/container.py", line 253, in forward
#     input = module(input)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1778, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1789, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/upsampling.py", line 175, in forward
#     return F.interpolate(
#   File "/root/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/functional.py", line 4886, in interpolate
#     return torch._C._nn.upsample_trilinear3d(
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 5.00 GiB. GPU 0 has a total capacity of 31.36 GiB of which 4.27 GiB is free. Including non-PyTorch memory, this process has 27.08 GiB memory in use. Of the allocated memory 25.14 GiB is allocated by PyTorch, and 1.36 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
