# %%
# ==========================================
# 🎛️ EXPERIMENT CONTROL PANEL
# ==========================================

# 1. 实验标识
# 建议在名字里加上 loss 类型，方便区分，例如 "_L1"
EXPERIMENT_NAME = "run_weight_Alldata"  
GPU_ID = 0

# 2. 物理参数 (Z1024 数据)
SPACING_Z = 0.0362  
SPACING_X = 0.2     

# 3. 训练超参
BATCH_SIZE = 2
LR_G = 0.0002
LR_D_RATIO = 0.1    

# [修改点 1]：配置损失函数类型和权重
# -----------------------------------------------------------
PIXEL_LOSS_TYPE = 'L1'   # 选项: 'L1' (MAE) 或 'L2' (MSE)
LAMBDA_PIXEL = 100.0     # 权重推荐: L1 通常设为 100.0; L2 通常设为 1.0 或 10.0
# -----------------------------------------------------------

# 4. 增强开关
USE_AUGMENTATION = False 

# 5. 路径配置G:\train_data\AUGAN_DATA_Nii
DATA_ROOT = "/mnt/g/train_data/AUGAN_DATA_Nii"
CHECKPOINT_ROOT = "/mnt/g/checkpoints"

# ==========================================
# ==========================================
# 自动生成命令行 (修复版 - 移除空行)
# ==========================================
aug_flags = "" if USE_AUGMENTATION else "--no_flip --no_elastic"

# 注意：不要在行与行之间留空行！
cmd = f"""
python train.py \\
    --dataroot {DATA_ROOT} \\
    --name {EXPERIMENT_NAME} \\
    --model augan \\
    --netG unet_3d \\
    --batch_size {BATCH_SIZE} \\
    --pixel_loss {PIXEL_LOSS_TYPE} \\
    --lambda_pixel {LAMBDA_PIXEL} \\
    --lr {LR_G} \\
    --lr_d_ratio {LR_D_RATIO} \\
    --spacing_z {SPACING_Z} \\
    --spacing_x {SPACING_X} \\
    {aug_flags} \\
    --gpu_ids {GPU_ID} \\
    --checkpoints_dir {CHECKPOINT_ROOT} \\
    --num_workers 16 
"""

print("🚀 Ready to launch command:")
print(cmd)
# Out:
# 🚀 Ready to launch command:
#
# python train.py \
#     --dataroot /mnt/g/train_data/AUGAN_DATA_Nii \
#     --name run_weight_Alldata \
#     --model augan \
#     --netG unet_3d \
#     --batch_size 2 \
#     --pixel_loss L1 \
#     --lambda_pixel 100.0 \
#     --lr 0.0002 \
#     --lr_d_ratio 0.1 \
#     --spacing_z 0.0362 \
#     --spacing_x 0.2 \
#     --no_flip --no_elastic \
#     --gpu_ids 0 \
#     --checkpoints_dir /mnt/g/checkpoints \
#     --num_workers 16

# %%
# 运行训练脚本
# 注意：感叹号 ! 表示调用系统终端执行命令
# !{cmd}
# Out:
# Traceback (most recent call last):
#   File "train.py", line 18, in <module>
#     from data import create_dataset
#   File "/home/liujia/AUGAN_3D_Recon/data/__init__.py", line 7, in <module>
#     from data.ultrasound_dataset import UltrasoundDataset
#   File "/home/liujia/AUGAN_3D_Recon/data/ultrasound_dataset.py", line 9, in <module>
#     from data.transforms import get_3d_transform, ElasticDeformation
# ImportError: cannot import name 'get_3d_transform' from 'data.transforms' (/home/liujia/AUGAN_3D_Recon/data/transforms.py)

# %%
# 查看最新的训练结果图 (可以反复运行此格)
show_latest_visuals(EXPERIMENT_NAME)
