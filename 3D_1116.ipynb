# %%
# !python train.py
# Out:
# Dataset [UltrasoundDataset] created. Size: 552, Batch Size: 1, Shuffle: True, Workers: 4
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
#
# ================================================================================
#                      🚀 AUGAN TRAINING CONFIGURATION SUMMARY
# ================================================================================
# [1] 🖥️  Hardware & Environment
#   - Device:           cuda:0
#   - GPU Name:         NVIDIA GeForce RTX 4060
#   - CUDA Version:     11.8
#   - PyTorch Version:  2.4.1
#   - Output Root:      ./project_assets/experiments
#   - TensorBoard:      tensorboard --logdir ./project_assets/experiments/run_01_baseline_aniso/logs
#
# [2] 💿 Data & Physics
#   - Data Root:        /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024
#   - Dataset Size:     552 volumes
#   - Anisotropic Sigma:(276.24309392265195, 50.0, 50.0) (Z-smoothness boosted!)
#   - Physics Spacing:  Z=0.0362mm, X=0.2mm
#   - Patch Size:       (D=256, H=64, W=64)
#   - Batch Size:       1
#   - Num Workers:      4
#   - No Flip:          False
#
# [3] 🧠 Model Hyperparameters
#   - Generator:        unet_3d (6-level recursive 3D U-Net)
#   - Discriminator:    pixel (3-layer 3D PatchGAN)
#   - Norm Layer:       instance
#   - Dropout:          Enabled
#   - Params (G):       116.932 M
#   - Params (D):       11.052 M
#
# [4] ⚙️  Training Strategy
#   - Epochs:           100 (Keep LR) + 100 (Decay LR)
#   - LR Policy:        linear
#   - Learning Rate:    G=0.0002, D=0.0002 (Ratio=1.0)
#   - GAN Mode:         vanilla
#   - Lambda L2:        100.0 (Pixel Loss Weight)
# ================================================================================
#
#
# Start Epoch 1 / 200
# Epoch 1:  18%|▏| 99/552 [01:39<08:46,  1.16s/batch, D_Real=0.512, G_GAN=1.948, G
# [Epoch 1 | Step 100] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.96] | Mean: -0.442
#   Fake | Range: [-0.99, 0.23] | Mean: -0.743
#   Real | Range: [-1.00, 0.95] | Mean: -0.860
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_001_step_100.png
# Epoch 1:  36%|▎| 199/552 [03:26<06:58,  1.19s/batch, D_Real=0.971, G_GAN=0.924,
# [Epoch 1 | Step 200] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.91] | Mean: -0.310
#   Fake | Range: [-0.99, 0.32] | Mean: -0.678
#   Real | Range: [-1.00, 0.94] | Mean: -0.762
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_001_step_200.png
# Epoch 1:  54%|▌| 299/552 [05:07<04:58,  1.18s/batch, D_Real=1.258, G_GAN=0.440,
# [Epoch 1 | Step 300] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.79] | Mean: -0.474
#   Fake | Range: [-0.98, 0.32] | Mean: -0.778
#   Real | Range: [-1.00, 0.79] | Mean: -0.888
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_001_step_300.png
# Epoch 1:  72%|▋| 399/552 [06:57<01:24,  1.80batch/s, D_Real=0.241, G_GAN=1.583,
# [Epoch 1 | Step 400] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 1.00] | Mean: -0.302
#   Fake | Range: [-0.99, 0.61] | Mean: -0.713
#   Real | Range: [-1.00, 1.00] | Mean: -0.711
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_001_step_400.png
# Epoch 1:  90%|▉| 499/552 [08:34<00:42,  1.24batch/s, D_Real=0.111, G_GAN=1.560,
# [Epoch 1 | Step 500] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.97] | Mean: -0.450
#   Fake | Range: [-0.99, 0.61] | Mean: -0.785
#   Real | Range: [-1.00, 0.97] | Mean: -0.835
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_001_step_500.png
#
# Start Epoch 2 / 200
# Epoch 2:   9%| | 47/552 [00:53<04:00,  2.10batch/s, D_Real=0.147, G_GAN=1.877, G
# [Epoch 2 | Step 600] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.97] | Mean: -0.479
#   Fake | Range: [-0.99, 0.51] | Mean: -0.818
#   Real | Range: [-1.00, 0.96] | Mean: -0.861
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_002_step_600.png
# Epoch 2:  27%|▎| 147/552 [02:36<06:04,  1.11batch/s, D_Real=0.177, G_GAN=3.280,
# [Epoch 2 | Step 700] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.98] | Mean: -0.366
#   Fake | Range: [-1.00, 0.42] | Mean: -0.728
#   Real | Range: [-1.00, 0.98] | Mean: -0.805
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_002_step_700.png
# Epoch 2:  45%|▍| 247/552 [04:15<03:52,  1.31batch/s, D_Real=0.533, G_GAN=1.300,
# [Epoch 2 | Step 800] 📊 Image Stats Check:
#   LQ   | Range: [-1.00, 0.98] | Mean: -0.187
#   Fake | Range: [-0.99, 0.62] | Mean: -0.636
#   Real | Range: [-1.00, 0.98] | Mean: -0.638
#   🖼️  Sample saved: ./project_assets/experiments/run_01_baseline_aniso/web_images/epoch_002_step_800.png
# Traceback (most recent call last):
#   File "train.py", line 196, in <module>
#     for i, data in enumerate(progress_bar):
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1327, in _next_data
#     idx, data = self._get_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1283, in _get_data
#     success, data = self._try_get_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1131, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
# ^C

# %%
! python train.py \
    --dataroot /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024 \
    --name augan_3d_z1024_phys_run \
    --lambda_L2 1.0 \
    --lr_d_ratio 0.1 \
    --batch_size 2
# Out:
# Dataset [UltrasoundDataset] created. Size: 552, Batch Size: 2, Shuffle: True, Workers: 4
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024
#   - Dataset Size:  276 volumes
#   - Batch Size:    2
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.181 (Correcting pixel aspect)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0002, D=2e-05
#   - L2 Weight:     1.0
# ================================================================================
#
# Epoch 1:  50%|██  | 138/276 [04:18<04:18,  1.88s/batch, G_GAN=0.646, G_L2=0.131]
# Traceback (most recent call last):
#   File "train.py", line 152, in <module>
#     for i, data in enumerate(progress_bar):
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1327, in _next_data
#     idx, data = self._get_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1283, in _get_data
#     success, data = self._try_get_data()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1131, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
# ^C

# %%
! python train.py \
    --dataroot /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024 \
    --name augan_3d_z1024_phys_run \
    --lambda_L2 1.0 \
    --lr_d_ratio 0.1 \
    --batch_size 2 \
    --no_flip \
    --no_elastic
# Out:
# Dataset [UltrasoundDataset] created. Size: 552, Batch Size: 2, Shuffle: True, Workers: 4
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024
#   - Dataset Size:  276 volumes
#   - Batch Size:    2
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.181 (Height compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0002, D=2e-05
#   - L2 Weight:     1.0
# ================================================================================
#
# Epoch 1/200: 100%|█| 276/276 [02:04<00:00,  2.22batch/s, G_GAN=0.664, G_L2=0.106
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 124 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7826
#       ├─ G_Adversarial: 	 0.6239
#       └─ G_Pixelwise (L2): 	 0.1587
#     Discriminator (D): 	 Total ≈ 1.0230
#       ├─ D_Real_Loss: 	 0.9843
#       └─ D_Fake_Loss: 	 1.0617
# --------------------------------------------------------------------------------
#
# Epoch 2/200:  27%|▎| 74/276 [00:34<01:28,  2.27batch/s, G_GAN=0.695, G_L2=0.093]^C
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x73ea80686ee0>
# Traceback (most recent call last):
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1477, in __del__
#     self._shutdown_workers()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1441, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# Epoch 2/200:  27%|▎| 75/276 [00:35<01:33,  2.14batch/s, G_GAN=0.695, G_L2=0.093]
# Traceback (most recent call last):
#   File "train.py", line 173, in <module>
#     model.optimize_parameters()
#   File "/home/liujia/AUGAN_3D_Recon/models/augan_model.py", line 137, in optimize_parameters
#     self.backward_D()                # 计算 D 的反向传播
#   File "/home/liujia/AUGAN_3D_Recon/models/augan_model.py", line 113, in backward_D
#     self.loss_D.backward()
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/home/liujia/miniconda3/envs/augan_3d/lib/python3.8/site-packages/torch/autograd/graph.py", line 769, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %%
! python train.py \
    --dataroot /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024 \
    --name augan_3d_z1024_baseline \
    --model augan \
    --netG unet_3d \
    --batch_size 2 \
    --lambda_L2 1.0 \
    --lr 0.0002 \
    --lr_d_ratio 0.1 \
    --spacing_z 0.0362 \
    --spacing_x 0.2 \
    --no_flip \
    --no_elastic
# Out:
# Dataset [UltrasoundDataset] created. Size: 552, Batch Size: 2, Shuffle: True, Workers: 4
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 2
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_L2: 1.0                           	[default: 100.0]
#                        lr: 0.0002
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: augan_3d_z1024_baseline       	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: instance
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 4
#                 output_nc: 1
#              patch_size_d: 256
#              patch_size_h: 64
#              patch_size_w: 64
#                     phase: train
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024
#   - Dataset Size:  276 volumes
#   - Batch Size:    2
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0002, D=2e-05
#   - L2 Weight:     1.0
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█████████████████| 276/276 [02:03<00:00,  2.23batch/s, G_L2=0.089]
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 124 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7803
#       ├─ G_Adversarial: 	 0.6197
#       └─ G_Pixelwise (L2): 	 0.1606
#     Discriminator (D): 	 Total ≈ 1.0248
#       ├─ D_Real_Loss: 	 0.9845
#       └─ D_Fake_Loss: 	 1.0652
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 1 Visual Saved: epoch_001.png
#   📦 NIfTI Saved: epoch_001_fake.nii.gz
#
# Start Epoch 2 / 200
# Epoch 2: 100%|█████████████████| 276/276 [01:59<00:00,  2.30batch/s, G_L2=0.091]
# --------------------------------------------------------------------------------
# END OF EPOCH 2 / 200 	 Time Taken: 120 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7704
#       ├─ G_Adversarial: 	 0.6779
#       └─ G_Pixelwise (L2): 	 0.0924
#     Discriminator (D): 	 Total ≈ 0.7441
#       ├─ D_Real_Loss: 	 0.7448
#       └─ D_Fake_Loss: 	 0.7435
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 2 Visual Saved: epoch_002.png
#   📦 NIfTI Saved: epoch_002_fake.nii.gz
#
# Start Epoch 3 / 200
# Epoch 3: 100%|█████████████████| 276/276 [01:56<00:00,  2.37batch/s, G_L2=0.077]
# --------------------------------------------------------------------------------
# END OF EPOCH 3 / 200 	 Time Taken: 116 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7685
#       ├─ G_Adversarial: 	 0.6885
#       └─ G_Pixelwise (L2): 	 0.0800
#     Discriminator (D): 	 Total ≈ 0.7178
#       ├─ D_Real_Loss: 	 0.7183
#       └─ D_Fake_Loss: 	 0.7173
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 3 Visual Saved: epoch_003.png
#   📦 NIfTI Saved: epoch_003_fake.nii.gz
#
# Start Epoch 4 / 200
# Epoch 4: 100%|█████████████████| 276/276 [01:54<00:00,  2.41batch/s, G_L2=0.089]
# --------------------------------------------------------------------------------
# END OF EPOCH 4 / 200 	 Time Taken: 115 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7665
#       ├─ G_Adversarial: 	 0.6930
#       └─ G_Pixelwise (L2): 	 0.0735
#     Discriminator (D): 	 Total ≈ 0.7074
#       ├─ D_Real_Loss: 	 0.7079
#       └─ D_Fake_Loss: 	 0.7068
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 4 Visual Saved: epoch_004.png
#   📦 NIfTI Saved: epoch_004_fake.nii.gz
#
# Start Epoch 5 / 200
# Epoch 5: 100%|█████████████████| 276/276 [01:55<00:00,  2.39batch/s, G_L2=0.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 5 / 200 	 Time Taken: 115 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7650
#       ├─ G_Adversarial: 	 0.6951
#       └─ G_Pixelwise (L2): 	 0.0699
#     Discriminator (D): 	 Total ≈ 0.7026
#       ├─ D_Real_Loss: 	 0.7029
#       └─ D_Fake_Loss: 	 0.7024
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 5 Visual Saved: epoch_005.png
#   📦 NIfTI Saved: epoch_005_fake.nii.gz
# 💾 Saving checkpoints at epoch 5
#
# Start Epoch 6 / 200
# Epoch 6: 100%|█████████████████| 276/276 [02:02<00:00,  2.25batch/s, G_L2=0.094]
# --------------------------------------------------------------------------------
# END OF EPOCH 6 / 200 	 Time Taken: 123 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7651
#       ├─ G_Adversarial: 	 0.6963
#       └─ G_Pixelwise (L2): 	 0.0688
#     Discriminator (D): 	 Total ≈ 0.7003
#       ├─ D_Real_Loss: 	 0.7006
#       └─ D_Fake_Loss: 	 0.7000
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 6 Visual Saved: epoch_006.png
#   📦 NIfTI Saved: epoch_006_fake.nii.gz
#
# Start Epoch 7 / 200
# Epoch 7: 100%|█████████████████| 276/276 [02:01<00:00,  2.26batch/s, G_L2=0.083]
# --------------------------------------------------------------------------------
# END OF EPOCH 7 / 200 	 Time Taken: 122 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7661
#       ├─ G_Adversarial: 	 0.6972
#       └─ G_Pixelwise (L2): 	 0.0689
#     Discriminator (D): 	 Total ≈ 0.6987
#       ├─ D_Real_Loss: 	 0.6989
#       └─ D_Fake_Loss: 	 0.6986
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 7 Visual Saved: epoch_007.png
#   📦 NIfTI Saved: epoch_007_fake.nii.gz
#
# Start Epoch 8 / 200
# Epoch 8: 100%|█████████████████| 276/276 [02:04<00:00,  2.21batch/s, G_L2=0.067]
# --------------------------------------------------------------------------------
# END OF EPOCH 8 / 200 	 Time Taken: 125 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7671
#       ├─ G_Adversarial: 	 0.6982
#       └─ G_Pixelwise (L2): 	 0.0690
#     Discriminator (D): 	 Total ≈ 0.6979
#       ├─ D_Real_Loss: 	 0.6981
#       └─ D_Fake_Loss: 	 0.6977
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 8 Visual Saved: epoch_008.png
#   📦 NIfTI Saved: epoch_008_fake.nii.gz
#
# Start Epoch 9 / 200
# Epoch 9: 100%|█████████████████| 276/276 [02:06<00:00,  2.19batch/s, G_L2=0.070]
# --------------------------------------------------------------------------------
# END OF EPOCH 9 / 200 	 Time Taken: 126 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7685
#       ├─ G_Adversarial: 	 0.6985
#       └─ G_Pixelwise (L2): 	 0.0700
#     Discriminator (D): 	 Total ≈ 0.6975
#       ├─ D_Real_Loss: 	 0.6975
#       └─ D_Fake_Loss: 	 0.6975
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 9 Visual Saved: epoch_009.png
#   📦 NIfTI Saved: epoch_009_fake.nii.gz
#
# Start Epoch 10 / 200
# Epoch 10: 100%|████████████████| 276/276 [02:03<00:00,  2.23batch/s, G_L2=0.076]
# --------------------------------------------------------------------------------
# END OF EPOCH 10 / 200 	 Time Taken: 124 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7668
#       ├─ G_Adversarial: 	 0.6982
#       └─ G_Pixelwise (L2): 	 0.0686
#     Discriminator (D): 	 Total ≈ 0.6967
#       ├─ D_Real_Loss: 	 0.6970
#       └─ D_Fake_Loss: 	 0.6964
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 10 Visual Saved: epoch_010.png
#   📦 NIfTI Saved: epoch_010_fake.nii.gz
# 💾 Saving checkpoints at epoch 10
#
# Start Epoch 11 / 200
# Epoch 11: 100%|████████████████| 276/276 [02:07<00:00,  2.17batch/s, G_L2=0.061]
# --------------------------------------------------------------------------------
# END OF EPOCH 11 / 200 	 Time Taken: 127 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7669
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0688
#     Discriminator (D): 	 Total ≈ 0.6965
#       ├─ D_Real_Loss: 	 0.6966
#       └─ D_Fake_Loss: 	 0.6964
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 11 Visual Saved: epoch_011.png
#   📦 NIfTI Saved: epoch_011_fake.nii.gz
#
# Start Epoch 12 / 200
# Epoch 12: 100%|████████████████| 276/276 [01:58<00:00,  2.32batch/s, G_L2=0.054]
# --------------------------------------------------------------------------------
# END OF EPOCH 12 / 200 	 Time Taken: 119 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7673
#       ├─ G_Adversarial: 	 0.6989
#       └─ G_Pixelwise (L2): 	 0.0684
#     Discriminator (D): 	 Total ≈ 0.6963
#       ├─ D_Real_Loss: 	 0.6963
#       └─ D_Fake_Loss: 	 0.6963
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 12 Visual Saved: epoch_012.png
#   📦 NIfTI Saved: epoch_012_fake.nii.gz
#
# Start Epoch 13 / 200
# Epoch 13: 100%|████████████████| 276/276 [01:56<00:00,  2.37batch/s, G_L2=0.078]
# --------------------------------------------------------------------------------
# END OF EPOCH 13 / 200 	 Time Taken: 116 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7640
#       ├─ G_Adversarial: 	 0.6987
#       └─ G_Pixelwise (L2): 	 0.0653
#     Discriminator (D): 	 Total ≈ 0.6961
#       ├─ D_Real_Loss: 	 0.6962
#       └─ D_Fake_Loss: 	 0.6960
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 13 Visual Saved: epoch_013.png
#   📦 NIfTI Saved: epoch_013_fake.nii.gz
#
# Start Epoch 14 / 200
# Epoch 14: 100%|████████████████| 276/276 [01:55<00:00,  2.38batch/s, G_L2=0.061]
# --------------------------------------------------------------------------------
# END OF EPOCH 14 / 200 	 Time Taken: 116 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7647
#       ├─ G_Adversarial: 	 0.6996
#       └─ G_Pixelwise (L2): 	 0.0651
#     Discriminator (D): 	 Total ≈ 0.6959
#       ├─ D_Real_Loss: 	 0.6961
#       └─ D_Fake_Loss: 	 0.6956
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 14 Visual Saved: epoch_014.png
#   📦 NIfTI Saved: epoch_014_fake.nii.gz
#
# Start Epoch 15 / 200
# Epoch 15: 100%|████████████████| 276/276 [01:57<00:00,  2.34batch/s, G_L2=0.069]
# --------------------------------------------------------------------------------
# END OF EPOCH 15 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7617
#       ├─ G_Adversarial: 	 0.6984
#       └─ G_Pixelwise (L2): 	 0.0633
#     Discriminator (D): 	 Total ≈ 0.6958
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6961
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 15 Visual Saved: epoch_015.png
#   📦 NIfTI Saved: epoch_015_fake.nii.gz
# 💾 Saving checkpoints at epoch 15
#
# Start Epoch 16 / 200
# Epoch 16: 100%|████████████████| 276/276 [02:01<00:00,  2.26batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 16 / 200 	 Time Taken: 122 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7614
#       ├─ G_Adversarial: 	 0.6989
#       └─ G_Pixelwise (L2): 	 0.0625
#     Discriminator (D): 	 Total ≈ 0.6956
#       ├─ D_Real_Loss: 	 0.6959
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 16 Visual Saved: epoch_016.png
#   📦 NIfTI Saved: epoch_016_fake.nii.gz
#
# Start Epoch 17 / 200
# Epoch 17: 100%|████████████████| 276/276 [01:57<00:00,  2.35batch/s, G_L2=0.078]
# --------------------------------------------------------------------------------
# END OF EPOCH 17 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7626
#       ├─ G_Adversarial: 	 0.6996
#       └─ G_Pixelwise (L2): 	 0.0630
#     Discriminator (D): 	 Total ≈ 0.6957
#       ├─ D_Real_Loss: 	 0.6964
#       └─ D_Fake_Loss: 	 0.6951
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 17 Visual Saved: epoch_017.png
#   📦 NIfTI Saved: epoch_017_fake.nii.gz
#
# Start Epoch 18 / 200
# Epoch 18: 100%|████████████████| 276/276 [01:58<00:00,  2.32batch/s, G_L2=0.044]
# --------------------------------------------------------------------------------
# END OF EPOCH 18 / 200 	 Time Taken: 119 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7610
#       ├─ G_Adversarial: 	 0.6991
#       └─ G_Pixelwise (L2): 	 0.0618
#     Discriminator (D): 	 Total ≈ 0.6955
#       ├─ D_Real_Loss: 	 0.6956
#       └─ D_Fake_Loss: 	 0.6954
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 18 Visual Saved: epoch_018.png
#   📦 NIfTI Saved: epoch_018_fake.nii.gz
#
# Start Epoch 19 / 200
# Epoch 19: 100%|████████████████| 276/276 [01:58<00:00,  2.32batch/s, G_L2=0.052]
# --------------------------------------------------------------------------------
# END OF EPOCH 19 / 200 	 Time Taken: 119 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7598
#       ├─ G_Adversarial: 	 0.6984
#       └─ G_Pixelwise (L2): 	 0.0614
#     Discriminator (D): 	 Total ≈ 0.6956
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6956
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 19 Visual Saved: epoch_019.png
#   📦 NIfTI Saved: epoch_019_fake.nii.gz
#
# Start Epoch 20 / 200
# Epoch 20: 100%|████████████████| 276/276 [01:57<00:00,  2.34batch/s, G_L2=0.053]
# --------------------------------------------------------------------------------
# END OF EPOCH 20 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7601
#       ├─ G_Adversarial: 	 0.6992
#       └─ G_Pixelwise (L2): 	 0.0609
#     Discriminator (D): 	 Total ≈ 0.6953
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6951
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 20 Visual Saved: epoch_020.png
#   📦 NIfTI Saved: epoch_020_fake.nii.gz
# 💾 Saving checkpoints at epoch 20
#
# Start Epoch 21 / 200
# Epoch 21: 100%|████████████████| 276/276 [01:58<00:00,  2.33batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 21 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7592
#       ├─ G_Adversarial: 	 0.6988
#       └─ G_Pixelwise (L2): 	 0.0604
#     Discriminator (D): 	 Total ≈ 0.6951
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 21 Visual Saved: epoch_021.png
#   📦 NIfTI Saved: epoch_021_fake.nii.gz
#
# Start Epoch 22 / 200
# Epoch 22: 100%|████████████████| 276/276 [01:57<00:00,  2.35batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 22 / 200 	 Time Taken: 117 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7597
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0612
#     Discriminator (D): 	 Total ≈ 0.6954
#       ├─ D_Real_Loss: 	 0.6954
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 22 Visual Saved: epoch_022.png
#   📦 NIfTI Saved: epoch_022_fake.nii.gz
#
# Start Epoch 23 / 200
# Epoch 23: 100%|████████████████| 276/276 [01:58<00:00,  2.33batch/s, G_L2=0.069]
# --------------------------------------------------------------------------------
# END OF EPOCH 23 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7571
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6952
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 23 Visual Saved: epoch_023.png
#   📦 NIfTI Saved: epoch_023_fake.nii.gz
#
# Start Epoch 24 / 200
# Epoch 24: 100%|████████████████| 276/276 [01:58<00:00,  2.34batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 24 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7570
#       ├─ G_Adversarial: 	 0.6974
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6950
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 24 Visual Saved: epoch_024.png
#   📦 NIfTI Saved: epoch_024_fake.nii.gz
#
# Start Epoch 25 / 200
# Epoch 25: 100%|████████████████| 276/276 [02:01<00:00,  2.28batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 25 / 200 	 Time Taken: 121 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7580
#       ├─ G_Adversarial: 	 0.6982
#       └─ G_Pixelwise (L2): 	 0.0598
#     Discriminator (D): 	 Total ≈ 0.6951
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 25 Visual Saved: epoch_025.png
#   📦 NIfTI Saved: epoch_025_fake.nii.gz
# 💾 Saving checkpoints at epoch 25
#
# Start Epoch 26 / 200
# Epoch 26: 100%|████████████████| 276/276 [01:57<00:00,  2.34batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 26 / 200 	 Time Taken: 118 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7579
#       ├─ G_Adversarial: 	 0.6980
#       └─ G_Pixelwise (L2): 	 0.0599
#     Discriminator (D): 	 Total ≈ 0.6951
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6955
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 26 Visual Saved: epoch_026.png
#   📦 NIfTI Saved: epoch_026_fake.nii.gz
#
# Start Epoch 27 / 200
# Epoch 27: 100%|████████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.069]
# --------------------------------------------------------------------------------
# END OF EPOCH 27 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7569
#       ├─ G_Adversarial: 	 0.6978
#       └─ G_Pixelwise (L2): 	 0.0591
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6947
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 27 Visual Saved: epoch_027.png
#   📦 NIfTI Saved: epoch_027_fake.nii.gz
#
# Start Epoch 28 / 200
# Epoch 28: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.050]
# --------------------------------------------------------------------------------
# END OF EPOCH 28 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7567
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0590
#     Discriminator (D): 	 Total ≈ 0.6951
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 28 Visual Saved: epoch_028.png
#   📦 NIfTI Saved: epoch_028_fake.nii.gz
#
# Start Epoch 29 / 200
# Epoch 29: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 29 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7566
#       ├─ G_Adversarial: 	 0.6975
#       └─ G_Pixelwise (L2): 	 0.0592
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 29 Visual Saved: epoch_029.png
#   📦 NIfTI Saved: epoch_029_fake.nii.gz
#
# Start Epoch 30 / 200
# Epoch 30: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 30 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7573
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6951
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 30 Visual Saved: epoch_030.png
#   📦 NIfTI Saved: epoch_030_fake.nii.gz
# 💾 Saving checkpoints at epoch 30
#
# Start Epoch 31 / 200
# Epoch 31: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 31 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7573
#       ├─ G_Adversarial: 	 0.6979
#       └─ G_Pixelwise (L2): 	 0.0594
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6950
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 31 Visual Saved: epoch_031.png
#   📦 NIfTI Saved: epoch_031_fake.nii.gz
#
# Start Epoch 32 / 200
# Epoch 32: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.052]
# --------------------------------------------------------------------------------
# END OF EPOCH 32 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7566
#       ├─ G_Adversarial: 	 0.6979
#       └─ G_Pixelwise (L2): 	 0.0587
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 32 Visual Saved: epoch_032.png
#   📦 NIfTI Saved: epoch_032_fake.nii.gz
#
# Start Epoch 33 / 200
# Epoch 33: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 33 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7572
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 33 Visual Saved: epoch_033.png
#   📦 NIfTI Saved: epoch_033_fake.nii.gz
#
# Start Epoch 34 / 200
# Epoch 34: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 34 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7568
#       ├─ G_Adversarial: 	 0.6980
#       └─ G_Pixelwise (L2): 	 0.0588
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6950
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 34 Visual Saved: epoch_034.png
#   📦 NIfTI Saved: epoch_034_fake.nii.gz
#
# Start Epoch 35 / 200
# Epoch 35: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.048]
# --------------------------------------------------------------------------------
# END OF EPOCH 35 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7575
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0594
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6950
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 35 Visual Saved: epoch_035.png
#   📦 NIfTI Saved: epoch_035_fake.nii.gz
# 💾 Saving checkpoints at epoch 35
#
# Start Epoch 36 / 200
# Epoch 36: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 36 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7574
#       ├─ G_Adversarial: 	 0.6979
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6949
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 36 Visual Saved: epoch_036.png
#   📦 NIfTI Saved: epoch_036_fake.nii.gz
#
# Start Epoch 37 / 200
# Epoch 37: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 37 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7575
#       ├─ G_Adversarial: 	 0.6978
#       └─ G_Pixelwise (L2): 	 0.0597
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 37 Visual Saved: epoch_037.png
#   📦 NIfTI Saved: epoch_037_fake.nii.gz
#
# Start Epoch 38 / 200
# Epoch 38: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.050]
# --------------------------------------------------------------------------------
# END OF EPOCH 38 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7584
#       ├─ G_Adversarial: 	 0.6980
#       └─ G_Pixelwise (L2): 	 0.0604
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6949
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 38 Visual Saved: epoch_038.png
#   📦 NIfTI Saved: epoch_038_fake.nii.gz
#
# Start Epoch 39 / 200
# Epoch 39: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 39 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7586
#       ├─ G_Adversarial: 	 0.6985
#       └─ G_Pixelwise (L2): 	 0.0601
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 39 Visual Saved: epoch_039.png
#   📦 NIfTI Saved: epoch_039_fake.nii.gz
#
# Start Epoch 40 / 200
# Epoch 40: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 40 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7560
#       ├─ G_Adversarial: 	 0.6966
#       └─ G_Pixelwise (L2): 	 0.0594
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6940
#       └─ D_Fake_Loss: 	 0.6951
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 40 Visual Saved: epoch_040.png
#   📦 NIfTI Saved: epoch_040_fake.nii.gz
# 💾 Saving checkpoints at epoch 40
#
# Start Epoch 41 / 200
# Epoch 41: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 41 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7570
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0593
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6949
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 41 Visual Saved: epoch_041.png
#   📦 NIfTI Saved: epoch_041_fake.nii.gz
#
# Start Epoch 42 / 200
# Epoch 42: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.061]
# --------------------------------------------------------------------------------
# END OF EPOCH 42 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7582
#       ├─ G_Adversarial: 	 0.6980
#       └─ G_Pixelwise (L2): 	 0.0603
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6947
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 42 Visual Saved: epoch_042.png
#   📦 NIfTI Saved: epoch_042_fake.nii.gz
#
# Start Epoch 43 / 200
# Epoch 43: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.051]
# --------------------------------------------------------------------------------
# END OF EPOCH 43 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7574
#       ├─ G_Adversarial: 	 0.6974
#       └─ G_Pixelwise (L2): 	 0.0601
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6947
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 43 Visual Saved: epoch_043.png
#   📦 NIfTI Saved: epoch_043_fake.nii.gz
#
# Start Epoch 44 / 200
# Epoch 44: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 44 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7571
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 44 Visual Saved: epoch_044.png
#   📦 NIfTI Saved: epoch_044_fake.nii.gz
#
# Start Epoch 45 / 200
# Epoch 45: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.072]
# --------------------------------------------------------------------------------
# END OF EPOCH 45 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7577
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0601
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 45 Visual Saved: epoch_045.png
#   📦 NIfTI Saved: epoch_045_fake.nii.gz
# 💾 Saving checkpoints at epoch 45
#
# Start Epoch 46 / 200
# Epoch 46: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.063]
# --------------------------------------------------------------------------------
# END OF EPOCH 46 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7558
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0591
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 46 Visual Saved: epoch_046.png
#   📦 NIfTI Saved: epoch_046_fake.nii.gz
#
# Start Epoch 47 / 200
# Epoch 47: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 47 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7565
#       ├─ G_Adversarial: 	 0.6970
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 47 Visual Saved: epoch_047.png
#   📦 NIfTI Saved: epoch_047_fake.nii.gz
#
# Start Epoch 48 / 200
# Epoch 48: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.067]
# --------------------------------------------------------------------------------
# END OF EPOCH 48 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7569
#       ├─ G_Adversarial: 	 0.6973
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6944
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 48 Visual Saved: epoch_048.png
#   📦 NIfTI Saved: epoch_048_fake.nii.gz
#
# Start Epoch 49 / 200
# Epoch 49: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 49 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7573
#       ├─ G_Adversarial: 	 0.6975
#       └─ G_Pixelwise (L2): 	 0.0598
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 49 Visual Saved: epoch_049.png
#   📦 NIfTI Saved: epoch_049_fake.nii.gz
#
# Start Epoch 50 / 200
# Epoch 50: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.053]
# --------------------------------------------------------------------------------
# END OF EPOCH 50 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7574
#       ├─ G_Adversarial: 	 0.6970
#       └─ G_Pixelwise (L2): 	 0.0605
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6952
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 50 Visual Saved: epoch_050.png
#   📦 NIfTI Saved: epoch_050_fake.nii.gz
# 💾 Saving checkpoints at epoch 50
#
# Start Epoch 51 / 200
# Epoch 51: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.042]
# --------------------------------------------------------------------------------
# END OF EPOCH 51 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7572
#       ├─ G_Adversarial: 	 0.6975
#       └─ G_Pixelwise (L2): 	 0.0597
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6947
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 51 Visual Saved: epoch_051.png
#   📦 NIfTI Saved: epoch_051_fake.nii.gz
#
# Start Epoch 52 / 200
# Epoch 52: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.051]
# --------------------------------------------------------------------------------
# END OF EPOCH 52 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7564
#       ├─ G_Adversarial: 	 0.6973
#       └─ G_Pixelwise (L2): 	 0.0591
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 52 Visual Saved: epoch_052.png
#   📦 NIfTI Saved: epoch_052_fake.nii.gz
#
# Start Epoch 53 / 200
# Epoch 53: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 53 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7563
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 53 Visual Saved: epoch_053.png
#   📦 NIfTI Saved: epoch_053_fake.nii.gz
#
# Start Epoch 54 / 200
# Epoch 54: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 54 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7562
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 54 Visual Saved: epoch_054.png
#   📦 NIfTI Saved: epoch_054_fake.nii.gz
#
# Start Epoch 55 / 200
# Epoch 55: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 55 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7564
#       ├─ G_Adversarial: 	 0.6969
#       └─ G_Pixelwise (L2): 	 0.0595
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 55 Visual Saved: epoch_055.png
#   📦 NIfTI Saved: epoch_055_fake.nii.gz
# 💾 Saving checkpoints at epoch 55
#
# Start Epoch 56 / 200
# Epoch 56: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.075]
# --------------------------------------------------------------------------------
# END OF EPOCH 56 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7570
#       ├─ G_Adversarial: 	 0.6968
#       └─ G_Pixelwise (L2): 	 0.0602
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 56 Visual Saved: epoch_056.png
#   📦 NIfTI Saved: epoch_056_fake.nii.gz
#
# Start Epoch 57 / 200
# Epoch 57: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 57 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7556
#       ├─ G_Adversarial: 	 0.6966
#       └─ G_Pixelwise (L2): 	 0.0590
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 57 Visual Saved: epoch_057.png
#   📦 NIfTI Saved: epoch_057_fake.nii.gz
#
# Start Epoch 58 / 200
# Epoch 58: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.063]
# --------------------------------------------------------------------------------
# END OF EPOCH 58 / 200 	 Time Taken: 109 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7560
#       ├─ G_Adversarial: 	 0.6970
#       └─ G_Pixelwise (L2): 	 0.0590
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 58 Visual Saved: epoch_058.png
#   📦 NIfTI Saved: epoch_058_fake.nii.gz
#
# Start Epoch 59 / 200
# Epoch 59: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.051]
# --------------------------------------------------------------------------------
# END OF EPOCH 59 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7572
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0596
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 59 Visual Saved: epoch_059.png
#   📦 NIfTI Saved: epoch_059_fake.nii.gz
#
# Start Epoch 60 / 200
# Epoch 60: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 60 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7561
#       ├─ G_Adversarial: 	 0.6968
#       └─ G_Pixelwise (L2): 	 0.0593
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 60 Visual Saved: epoch_060.png
#   📦 NIfTI Saved: epoch_060_fake.nii.gz
# 💾 Saving checkpoints at epoch 60
#
# Start Epoch 61 / 200
# Epoch 61: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 61 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7566
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0599
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 61 Visual Saved: epoch_061.png
#   📦 NIfTI Saved: epoch_061_fake.nii.gz
#
# Start Epoch 62 / 200
# Epoch 62: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 62 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7563
#       ├─ G_Adversarial: 	 0.6971
#       └─ G_Pixelwise (L2): 	 0.0592
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 62 Visual Saved: epoch_062.png
#   📦 NIfTI Saved: epoch_062_fake.nii.gz
#
# Start Epoch 63 / 200
# Epoch 63: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.047]
# --------------------------------------------------------------------------------
# END OF EPOCH 63 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7554
#       ├─ G_Adversarial: 	 0.6969
#       └─ G_Pixelwise (L2): 	 0.0585
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6945
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 63 Visual Saved: epoch_063.png
#   📦 NIfTI Saved: epoch_063_fake.nii.gz
#
# Start Epoch 64 / 200
# Epoch 64: 100%|████████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 64 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7561
#       ├─ G_Adversarial: 	 0.6968
#       └─ G_Pixelwise (L2): 	 0.0592
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 64 Visual Saved: epoch_064.png
#   📦 NIfTI Saved: epoch_064_fake.nii.gz
#
# Start Epoch 65 / 200
# Epoch 65: 100%|████████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.046]
# ...
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6933
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 177 Visual Saved: epoch_177.png
#   📦 NIfTI Saved: epoch_177_fake.nii.gz
#
# Start Epoch 178 / 200
# Epoch 178: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 178 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000455 | D_lr = 0.0000046
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7482
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0543
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6930
#       └─ D_Fake_Loss: 	 0.6937
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 178 Visual Saved: epoch_178.png
#   📦 NIfTI Saved: epoch_178_fake.nii.gz
#
# Start Epoch 179 / 200
# Epoch 179: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 179 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000436 | D_lr = 0.0000044
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7487
#       ├─ G_Adversarial: 	 0.6941
#       └─ G_Pixelwise (L2): 	 0.0546
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6937
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 179 Visual Saved: epoch_179.png
#   📦 NIfTI Saved: epoch_179_fake.nii.gz
#
# Start Epoch 180 / 200
# Epoch 180: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.063]
# --------------------------------------------------------------------------------
# END OF EPOCH 180 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000416 | D_lr = 0.0000042
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7493
#       ├─ G_Adversarial: 	 0.6944
#       └─ G_Pixelwise (L2): 	 0.0549
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6933
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 180 Visual Saved: epoch_180.png
#   📦 NIfTI Saved: epoch_180_fake.nii.gz
# 💾 Saving checkpoints at epoch 180
#
# Start Epoch 181 / 200
# Epoch 181: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.047]
# --------------------------------------------------------------------------------
# END OF EPOCH 181 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000396 | D_lr = 0.0000040
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7487
#       ├─ G_Adversarial: 	 0.6942
#       └─ G_Pixelwise (L2): 	 0.0545
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6933
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 181 Visual Saved: epoch_181.png
#   📦 NIfTI Saved: epoch_181_fake.nii.gz
#
# Start Epoch 182 / 200
# Epoch 182: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 182 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000376 | D_lr = 0.0000038
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7488
#       ├─ G_Adversarial: 	 0.6944
#       └─ G_Pixelwise (L2): 	 0.0544
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6936
#       └─ D_Fake_Loss: 	 0.6932
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 182 Visual Saved: epoch_182.png
#   📦 NIfTI Saved: epoch_182_fake.nii.gz
#
# Start Epoch 183 / 200
# Epoch 183: 100%|███████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.067]
# --------------------------------------------------------------------------------
# END OF EPOCH 183 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000356 | D_lr = 0.0000036
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7494
#       ├─ G_Adversarial: 	 0.6943
#       └─ G_Pixelwise (L2): 	 0.0552
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6934
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 183 Visual Saved: epoch_183.png
#   📦 NIfTI Saved: epoch_183_fake.nii.gz
#
# Start Epoch 184 / 200
# Epoch 184: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 184 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000337 | D_lr = 0.0000034
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7486
#       ├─ G_Adversarial: 	 0.6942
#       └─ G_Pixelwise (L2): 	 0.0545
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6933
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 184 Visual Saved: epoch_184.png
#   📦 NIfTI Saved: epoch_184_fake.nii.gz
#
# Start Epoch 185 / 200
# Epoch 185: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.056]
# --------------------------------------------------------------------------------
# END OF EPOCH 185 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000317 | D_lr = 0.0000032
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7489
#       ├─ G_Adversarial: 	 0.6944
#       └─ G_Pixelwise (L2): 	 0.0545
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6936
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 185 Visual Saved: epoch_185.png
#   📦 NIfTI Saved: epoch_185_fake.nii.gz
# 💾 Saving checkpoints at epoch 185
#
# Start Epoch 186 / 200
# Epoch 186: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.051]
# --------------------------------------------------------------------------------
# END OF EPOCH 186 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000297 | D_lr = 0.0000030
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7481
#       ├─ G_Adversarial: 	 0.6940
#       └─ G_Pixelwise (L2): 	 0.0541
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6931
#       └─ D_Fake_Loss: 	 0.6934
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 186 Visual Saved: epoch_186.png
#   📦 NIfTI Saved: epoch_186_fake.nii.gz
#
# Start Epoch 187 / 200
# Epoch 187: 100%|███████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 187 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000277 | D_lr = 0.0000028
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7479
#       ├─ G_Adversarial: 	 0.6940
#       └─ G_Pixelwise (L2): 	 0.0539
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6933
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 187 Visual Saved: epoch_187.png
#   📦 NIfTI Saved: epoch_187_fake.nii.gz
#
# Start Epoch 188 / 200
# Epoch 188: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.053]
# --------------------------------------------------------------------------------
# END OF EPOCH 188 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000257 | D_lr = 0.0000026
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7493
#       ├─ G_Adversarial: 	 0.6944
#       └─ G_Pixelwise (L2): 	 0.0549
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6928
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 188 Visual Saved: epoch_188.png
#   📦 NIfTI Saved: epoch_188_fake.nii.gz
#
# Start Epoch 189 / 200
# Epoch 189: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.050]
# --------------------------------------------------------------------------------
# END OF EPOCH 189 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000238 | D_lr = 0.0000024
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7484
#       ├─ G_Adversarial: 	 0.6941
#       └─ G_Pixelwise (L2): 	 0.0542
#     Discriminator (D): 	 Total ≈ 0.6934
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6932
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 189 Visual Saved: epoch_189.png
#   📦 NIfTI Saved: epoch_189_fake.nii.gz
#
# Start Epoch 190 / 200
# Epoch 190: 100%|███████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 190 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000218 | D_lr = 0.0000022
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7486
#       ├─ G_Adversarial: 	 0.6946
#       └─ G_Pixelwise (L2): 	 0.0539
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6926
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 190 Visual Saved: epoch_190.png
#   📦 NIfTI Saved: epoch_190_fake.nii.gz
# 💾 Saving checkpoints at epoch 190
#
# Start Epoch 191 / 200
# Epoch 191: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.053]
# --------------------------------------------------------------------------------
# END OF EPOCH 191 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000198 | D_lr = 0.0000020
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7492
#       ├─ G_Adversarial: 	 0.6945
#       └─ G_Pixelwise (L2): 	 0.0548
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6927
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 191 Visual Saved: epoch_191.png
#   📦 NIfTI Saved: epoch_191_fake.nii.gz
#
# Start Epoch 192 / 200
# Epoch 192: 100%|███████████████| 276/276 [01:49<00:00,  2.52batch/s, G_L2=0.044]
# --------------------------------------------------------------------------------
# END OF EPOCH 192 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000178 | D_lr = 0.0000018
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7484
#       ├─ G_Adversarial: 	 0.6942
#       └─ G_Pixelwise (L2): 	 0.0542
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6936
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 192 Visual Saved: epoch_192.png
#   📦 NIfTI Saved: epoch_192_fake.nii.gz
#
# Start Epoch 193 / 200
# Epoch 193: 100%|███████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.067]
# --------------------------------------------------------------------------------
# END OF EPOCH 193 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000158 | D_lr = 0.0000016
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7480
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0545
#     Discriminator (D): 	 Total ≈ 0.6933
#       ├─ D_Real_Loss: 	 0.6931
#       └─ D_Fake_Loss: 	 0.6935
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 193 Visual Saved: epoch_193.png
#   📦 NIfTI Saved: epoch_193_fake.nii.gz
#
# Start Epoch 194 / 200
# Epoch 194: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 194 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000139 | D_lr = 0.0000014
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7478
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0539
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6930
#       └─ D_Fake_Loss: 	 0.6932
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 194 Visual Saved: epoch_194.png
#   📦 NIfTI Saved: epoch_194_fake.nii.gz
#
# Start Epoch 195 / 200
# Epoch 195: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 195 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000119 | D_lr = 0.0000012
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7475
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0536
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 195 Visual Saved: epoch_195.png
#   📦 NIfTI Saved: epoch_195_fake.nii.gz
# 💾 Saving checkpoints at epoch 195
#
# Start Epoch 196 / 200
# Epoch 196: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 196 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000099 | D_lr = 0.0000010
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7482
#       ├─ G_Adversarial: 	 0.6942
#       └─ G_Pixelwise (L2): 	 0.0541
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6928
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 196 Visual Saved: epoch_196.png
#   📦 NIfTI Saved: epoch_196_fake.nii.gz
#
# Start Epoch 197 / 200
# Epoch 197: 100%|███████████████| 276/276 [01:50<00:00,  2.50batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 197 / 200 	 Time Taken: 111 sec
#   Learning Rates: 	 G_lr = 0.0000079 | D_lr = 0.0000008
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7478
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0543
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6930
#       └─ D_Fake_Loss: 	 0.6934
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 197 Visual Saved: epoch_197.png
#   📦 NIfTI Saved: epoch_197_fake.nii.gz
#
# Start Epoch 198 / 200
# Epoch 198: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.056]
# --------------------------------------------------------------------------------
# END OF EPOCH 198 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000059 | D_lr = 0.0000006
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7478
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0543
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6930
#       └─ D_Fake_Loss: 	 0.6934
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 198 Visual Saved: epoch_198.png
#   📦 NIfTI Saved: epoch_198_fake.nii.gz
#
# Start Epoch 199 / 200
# Epoch 199: 100%|███████████████| 276/276 [01:49<00:00,  2.51batch/s, G_L2=0.048]
# --------------------------------------------------------------------------------
# END OF EPOCH 199 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000040 | D_lr = 0.0000004
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7481
#       ├─ G_Adversarial: 	 0.6940
#       └─ G_Pixelwise (L2): 	 0.0540
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6928
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 199 Visual Saved: epoch_199.png
#   📦 NIfTI Saved: epoch_199_fake.nii.gz
#
# Start Epoch 200 / 200
# Epoch 200: 100%|███████████████| 276/276 [01:50<00:00,  2.51batch/s, G_L2=0.053]
# --------------------------------------------------------------------------------
# END OF EPOCH 200 / 200 	 Time Taken: 110 sec
#   Learning Rates: 	 G_lr = 0.0000020 | D_lr = 0.0000002
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7479
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0542
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 200 Visual Saved: epoch_200.png
#   📦 NIfTI Saved: epoch_200_fake.nii.gz
# 💾 Saving checkpoints at epoch 200
# 🎉 Training Finished!
