# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import display, clear_output
import glob

# 设置工作目录 (确保指向项目根目录)
# 如果您的 notebook 在项目根目录下，就不需要改。
# os.chdir('/home/liujia/AUGAN_3D_Recon') 
print(f"📂 Current Working Directory: {os.getcwd()}")

def show_latest_visuals(experiment_name, output_root='./project_assets/experiments'):
    """
    自动查找并显示最新的训练采样图。
    """
    img_dir = os.path.join(output_root, experiment_name, 'web_images')
    
    if not os.path.exists(img_dir):
        print(f"⚠️ No images found in {img_dir}. Training might not have started or saved yet.")
        return

    # 找最新的 png
    list_of_files = glob.glob(os.path.join(img_dir, '*.png'))
    if not list_of_files:
        print("📭 No PNG files found yet.")
        return
        
    latest_file = max(list_of_files, key=os.path.getctime)
    
    # 显示
    img = mpimg.imread(latest_file)
    plt.figure(figsize=(15, 6)) # 宽一点，适应横向图
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"📸 Latest Visual: {os.path.basename(latest_file)}", fontsize=12)
    plt.show()
# Out:
# 📂 Current Working Directory: /home/liujia/AUGAN_3D_Recon

# %%
# ==========================================
# 🎛️ EXPERIMENT CONTROL PANEL
# ==========================================

# 1. 实验标识
# EXPERIMENT_NAME = "run_03_z1024_baseline_alldata"  # 每次新实验改个名
EXPERIMENT_NAME = "run_03_z1024_baseline_alldata_patch"  # 每次新实验改个名
GPU_ID = 0

# 2. 物理参数 (Z1024 数据)
SPACING_Z = 0.0362  # 深度间距
SPACING_X = 0.2     # 侧向间距

# 3. 训练超参
BATCH_SIZE = 2
LR_G = 0.0002
LR_D_RATIO = 0.1    # D 的学习率是 G 的 0.1 倍
LAMBDA_L2 = 1.0     # 像素损失权重

# 4. 增强开关 (True=开启, False=关闭)
USE_AUGMENTATION = False 

# 5. 路径配置
# DATA_ROOT = "/home/liujia/AUGAN_Simplified/project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024"
DATA_ROOT = "/mnt/g/1024"
# ==========================================
# 自动生成命令行 (无需修改下方代码)
# ==========================================
aug_flags = "" if USE_AUGMENTATION else "--no_flip --no_elastic"

cmd = f"""
python train.py \
    --dataroot {DATA_ROOT} \
    --name {EXPERIMENT_NAME} \
    --model augan \
    --netG unet_3d \
    --batch_size {BATCH_SIZE} \
    --lambda_L2 {LAMBDA_L2} \
    --lr {LR_G} \
    --lr_d_ratio {LR_D_RATIO} \
    --spacing_z {SPACING_Z} \
    --spacing_x {SPACING_X} \
    {aug_flags} \
    --gpu_ids {GPU_ID} \
    --num_workers 16 
"""

print("🚀 Ready to launch command:")
print(cmd)
# Out:
# 🚀 Ready to launch command:
#
# python train.py     --dataroot /mnt/g/1024     --name run_03_z1024_baseline_alldata     --model augan     --netG unet_3d     --batch_size 2     --lambda_L2 1.0     --lr 0.0002     --lr_d_ratio 0.1     --spacing_z 0.0362     --spacing_x 0.2     --no_flip --no_elastic     --gpu_ids 0     --num_workers 16

# %%
# 运行训练脚本
# 注意：感叹号 ! 表示调用系统终端执行命令
# !{cmd}
# Out:
# Dataset [UltrasoundDataset] created. Size: 959, Batch Size: 2, Shuffle: True, Workers: 16
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 2
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: /mnt/g/1024                   	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_L2: 1.0                           	[default: 100.0]
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: run_03_z1024_baseline_alldata 	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: instance
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 16                            	[default: 4]
#                 output_nc: 1
#              patch_size_d: 256
#              patch_size_h: 64
#              patch_size_w: 64
#                     phase: train
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /mnt/g/1024
#   - Dataset Size:  479 volumes
#   - Batch Size:    2
#   - Patch Size:    [D=256, H=64, W=64]
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0002, D=2e-05
#   - L2 Weight:     1.0
#   - Augmentation:  No Flip, No Elastic
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█████████████████| 479/479 [03:38<00:00,  2.19batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 219 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7604
#       ├─ G_Adversarial: 	 0.6316
#       └─ G_Pixelwise (L2): 	 0.1288
#     Discriminator (D): 	 Total ≈ 0.9621
#       ├─ D_Real_Loss: 	 0.9253
#       └─ D_Fake_Loss: 	 0.9990
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 1 Visual Saved: epoch_001.png
#   📦 NIfTI Saved: epoch_001_fake.nii.gz
#
# Start Epoch 2 / 200
# Epoch 2: 100%|█████████████████| 479/479 [03:38<00:00,  2.19batch/s, G_L2=0.082]
# --------------------------------------------------------------------------------
# END OF EPOCH 2 / 200 	 Time Taken: 219 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7522
#       ├─ G_Adversarial: 	 0.6857
#       └─ G_Pixelwise (L2): 	 0.0665
#     Discriminator (D): 	 Total ≈ 0.7295
#       ├─ D_Real_Loss: 	 0.7304
#       └─ D_Fake_Loss: 	 0.7286
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 2 Visual Saved: epoch_002.png
#   📦 NIfTI Saved: epoch_002_fake.nii.gz
#
# Start Epoch 3 / 200
# Epoch 3: 100%|█████████████████| 479/479 [03:34<00:00,  2.23batch/s, G_L2=0.095]
# --------------------------------------------------------------------------------
# END OF EPOCH 3 / 200 	 Time Taken: 215 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7536
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0555
#     Discriminator (D): 	 Total ≈ 0.7095
#       ├─ D_Real_Loss: 	 0.7097
#       └─ D_Fake_Loss: 	 0.7093
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 3 Visual Saved: epoch_003.png
#   📦 NIfTI Saved: epoch_003_fake.nii.gz
#
# Start Epoch 4 / 200
# Epoch 4: 100%|█████████████████| 479/479 [03:31<00:00,  2.26batch/s, G_L2=0.004]
# --------------------------------------------------------------------------------
# END OF EPOCH 4 / 200 	 Time Taken: 212 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7543
#       ├─ G_Adversarial: 	 0.7028
#       └─ G_Pixelwise (L2): 	 0.0515
#     Discriminator (D): 	 Total ≈ 0.7033
#       ├─ D_Real_Loss: 	 0.7037
#       └─ D_Fake_Loss: 	 0.7030
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 4 Visual Saved: epoch_004.png
#   📦 NIfTI Saved: epoch_004_fake.nii.gz
#
# Start Epoch 5 / 200
# Epoch 5: 100%|█████████████████| 479/479 [03:31<00:00,  2.26batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 5 / 200 	 Time Taken: 212 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7539
#       ├─ G_Adversarial: 	 0.7041
#       └─ G_Pixelwise (L2): 	 0.0497
#     Discriminator (D): 	 Total ≈ 0.7021
#       ├─ D_Real_Loss: 	 0.7029
#       └─ D_Fake_Loss: 	 0.7013
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 5 Visual Saved: epoch_005.png
#   📦 NIfTI Saved: epoch_005_fake.nii.gz
# 💾 Saving checkpoints at epoch 5
#
# Start Epoch 6 / 200
# Epoch 6: 100%|█████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.050]
# --------------------------------------------------------------------------------
# END OF EPOCH 6 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7514
#       ├─ G_Adversarial: 	 0.7024
#       └─ G_Pixelwise (L2): 	 0.0489
#     Discriminator (D): 	 Total ≈ 0.6995
#       ├─ D_Real_Loss: 	 0.6992
#       └─ D_Fake_Loss: 	 0.6997
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 6 Visual Saved: epoch_006.png
#   📦 NIfTI Saved: epoch_006_fake.nii.gz
#
# Start Epoch 7 / 200
# Epoch 7: 100%|█████████████████| 479/479 [03:16<00:00,  2.43batch/s, G_L2=0.016]
# --------------------------------------------------------------------------------
# END OF EPOCH 7 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7515
#       ├─ G_Adversarial: 	 0.7037
#       └─ G_Pixelwise (L2): 	 0.0478
#     Discriminator (D): 	 Total ≈ 0.6984
#       ├─ D_Real_Loss: 	 0.6990
#       └─ D_Fake_Loss: 	 0.6978
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 7 Visual Saved: epoch_007.png
#   📦 NIfTI Saved: epoch_007_fake.nii.gz
#
# Start Epoch 8 / 200
# Epoch 8: 100%|█████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.072]
# --------------------------------------------------------------------------------
# END OF EPOCH 8 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7514
#       ├─ G_Adversarial: 	 0.7041
#       └─ G_Pixelwise (L2): 	 0.0474
#     Discriminator (D): 	 Total ≈ 0.6977
#       ├─ D_Real_Loss: 	 0.6977
#       └─ D_Fake_Loss: 	 0.6978
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 8 Visual Saved: epoch_008.png
#   📦 NIfTI Saved: epoch_008_fake.nii.gz
#
# Start Epoch 9 / 200
# Epoch 9: 100%|█████████████████| 479/479 [03:15<00:00,  2.45batch/s, G_L2=0.045]
# --------------------------------------------------------------------------------
# END OF EPOCH 9 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7500
#       ├─ G_Adversarial: 	 0.7025
#       └─ G_Pixelwise (L2): 	 0.0474
#     Discriminator (D): 	 Total ≈ 0.6972
#       ├─ D_Real_Loss: 	 0.6973
#       └─ D_Fake_Loss: 	 0.6971
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 9 Visual Saved: epoch_009.png
#   📦 NIfTI Saved: epoch_009_fake.nii.gz
#
# Start Epoch 10 / 200
# Epoch 10: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 10 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7490
#       ├─ G_Adversarial: 	 0.7018
#       └─ G_Pixelwise (L2): 	 0.0472
#     Discriminator (D): 	 Total ≈ 0.6971
#       ├─ D_Real_Loss: 	 0.6973
#       └─ D_Fake_Loss: 	 0.6969
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 10 Visual Saved: epoch_010.png
#   📦 NIfTI Saved: epoch_010_fake.nii.gz
# 💾 Saving checkpoints at epoch 10
#
# Start Epoch 11 / 200
# Epoch 11: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 11 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7479
#       ├─ G_Adversarial: 	 0.7017
#       └─ G_Pixelwise (L2): 	 0.0463
#     Discriminator (D): 	 Total ≈ 0.6966
#       ├─ D_Real_Loss: 	 0.6967
#       └─ D_Fake_Loss: 	 0.6965
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 11 Visual Saved: epoch_011.png
#   📦 NIfTI Saved: epoch_011_fake.nii.gz
#
# Start Epoch 12 / 200
# Epoch 12: 100%|████████████████| 479/479 [03:15<00:00,  2.45batch/s, G_L2=0.031]
# --------------------------------------------------------------------------------
# END OF EPOCH 12 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7462
#       ├─ G_Adversarial: 	 0.7010
#       └─ G_Pixelwise (L2): 	 0.0452
#     Discriminator (D): 	 Total ≈ 0.6963
#       ├─ D_Real_Loss: 	 0.6967
#       └─ D_Fake_Loss: 	 0.6959
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 12 Visual Saved: epoch_012.png
#   📦 NIfTI Saved: epoch_012_fake.nii.gz
#
# Start Epoch 13 / 200
# Epoch 13: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.025]
# --------------------------------------------------------------------------------
# END OF EPOCH 13 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7473
#       ├─ G_Adversarial: 	 0.7019
#       └─ G_Pixelwise (L2): 	 0.0454
#     Discriminator (D): 	 Total ≈ 0.6966
#       ├─ D_Real_Loss: 	 0.6969
#       └─ D_Fake_Loss: 	 0.6963
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 13 Visual Saved: epoch_013.png
#   📦 NIfTI Saved: epoch_013_fake.nii.gz
#
# Start Epoch 14 / 200
# Epoch 14: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.036]
# --------------------------------------------------------------------------------
# END OF EPOCH 14 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7432
#       ├─ G_Adversarial: 	 0.6992
#       └─ G_Pixelwise (L2): 	 0.0439
#     Discriminator (D): 	 Total ≈ 0.6954
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 14 Visual Saved: epoch_014.png
#   📦 NIfTI Saved: epoch_014_fake.nii.gz
#
# Start Epoch 15 / 200
# Epoch 15: 100%|████████████████| 479/479 [03:15<00:00,  2.46batch/s, G_L2=0.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 15 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7445
#       ├─ G_Adversarial: 	 0.7000
#       └─ G_Pixelwise (L2): 	 0.0444
#     Discriminator (D): 	 Total ≈ 0.6957
#       ├─ D_Real_Loss: 	 0.6958
#       └─ D_Fake_Loss: 	 0.6956
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 15 Visual Saved: epoch_015.png
#   📦 NIfTI Saved: epoch_015_fake.nii.gz
# 💾 Saving checkpoints at epoch 15
#
# Start Epoch 16 / 200
# Epoch 16: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 16 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7423
#       ├─ G_Adversarial: 	 0.6994
#       └─ G_Pixelwise (L2): 	 0.0430
#     Discriminator (D): 	 Total ≈ 0.6955
#       ├─ D_Real_Loss: 	 0.6956
#       └─ D_Fake_Loss: 	 0.6954
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 16 Visual Saved: epoch_016.png
#   📦 NIfTI Saved: epoch_016_fake.nii.gz
#
# Start Epoch 17 / 200
# Epoch 17: 100%|████████████████| 479/479 [03:21<00:00,  2.38batch/s, G_L2=0.076]
# --------------------------------------------------------------------------------
# END OF EPOCH 17 / 200 	 Time Taken: 201 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7407
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0421
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6956
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 17 Visual Saved: epoch_017.png
#   📦 NIfTI Saved: epoch_017_fake.nii.gz
#
# Start Epoch 18 / 200
# Epoch 18: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 18 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7411
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0429
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 18 Visual Saved: epoch_018.png
#   📦 NIfTI Saved: epoch_018_fake.nii.gz
#
# Start Epoch 19 / 200
# Epoch 19: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 19 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7408
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0422
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 19 Visual Saved: epoch_019.png
#   📦 NIfTI Saved: epoch_019_fake.nii.gz
#
# Start Epoch 20 / 200
# Epoch 20: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 20 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7390
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0414
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6952
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 20 Visual Saved: epoch_020.png
#   📦 NIfTI Saved: epoch_020_fake.nii.gz
# 💾 Saving checkpoints at epoch 20
#
# Start Epoch 21 / 200
# Epoch 21: 100%|████████████████| 479/479 [03:27<00:00,  2.31batch/s, G_L2=0.016]
# --------------------------------------------------------------------------------
# END OF EPOCH 21 / 200 	 Time Taken: 207 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7392
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0415
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6947
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 21 Visual Saved: epoch_021.png
#   📦 NIfTI Saved: epoch_021_fake.nii.gz
#
# Start Epoch 22 / 200
# Epoch 22: 100%|████████████████| 479/479 [03:36<00:00,  2.22batch/s, G_L2=0.045]
# --------------------------------------------------------------------------------
# END OF EPOCH 22 / 200 	 Time Taken: 216 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7392
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0416
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 22 Visual Saved: epoch_022.png
#   📦 NIfTI Saved: epoch_022_fake.nii.gz
#
# Start Epoch 23 / 200
# Epoch 23: 100%|████████████████| 479/479 [03:37<00:00,  2.20batch/s, G_L2=0.003]
# --------------------------------------------------------------------------------
# END OF EPOCH 23 / 200 	 Time Taken: 217 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7411
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0425
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 23 Visual Saved: epoch_023.png
#   📦 NIfTI Saved: epoch_023_fake.nii.gz
#
# Start Epoch 24 / 200
# Epoch 24: 100%|████████████████| 479/479 [03:36<00:00,  2.21batch/s, G_L2=0.007]
# --------------------------------------------------------------------------------
# END OF EPOCH 24 / 200 	 Time Taken: 217 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7387
#       ├─ G_Adversarial: 	 0.6974
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 24 Visual Saved: epoch_024.png
#   📦 NIfTI Saved: epoch_024_fake.nii.gz
#
# Start Epoch 25 / 200
# Epoch 25: 100%|████████████████| 479/479 [03:34<00:00,  2.24batch/s, G_L2=0.025]
# --------------------------------------------------------------------------------
# END OF EPOCH 25 / 200 	 Time Taken: 214 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7379
#       ├─ G_Adversarial: 	 0.6972
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 25 Visual Saved: epoch_025.png
#   📦 NIfTI Saved: epoch_025_fake.nii.gz
# 💾 Saving checkpoints at epoch 25
#
# Start Epoch 26 / 200
# Epoch 26: 100%|████████████████| 479/479 [03:22<00:00,  2.36batch/s, G_L2=0.052]
# --------------------------------------------------------------------------------
# END OF EPOCH 26 / 200 	 Time Taken: 203 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7384
#       ├─ G_Adversarial: 	 0.6972
#       └─ G_Pixelwise (L2): 	 0.0412
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6950
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 26 Visual Saved: epoch_026.png
#   📦 NIfTI Saved: epoch_026_fake.nii.gz
#
# Start Epoch 27 / 200
# Epoch 27: 100%|████████████████| 479/479 [03:24<00:00,  2.34batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 27 / 200 	 Time Taken: 205 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7381
#       ├─ G_Adversarial: 	 0.6975
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 27 Visual Saved: epoch_027.png
#   📦 NIfTI Saved: epoch_027_fake.nii.gz
#
# Start Epoch 28 / 200
# Epoch 28: 100%|████████████████| 479/479 [03:20<00:00,  2.39batch/s, G_L2=0.011]
# --------------------------------------------------------------------------------
# END OF EPOCH 28 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7391
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0414
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 28 Visual Saved: epoch_028.png
#   📦 NIfTI Saved: epoch_028_fake.nii.gz
#
# Start Epoch 29 / 200
# Epoch 29: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.013]
# --------------------------------------------------------------------------------
# END OF EPOCH 29 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6969
#       └─ G_Pixelwise (L2): 	 0.0403
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 29 Visual Saved: epoch_029.png
#   📦 NIfTI Saved: epoch_029_fake.nii.gz
#
# Start Epoch 30 / 200
# Epoch 30: 100%|████████████████| 479/479 [03:22<00:00,  2.37batch/s, G_L2=0.005]
# --------------------------------------------------------------------------------
# END OF EPOCH 30 / 200 	 Time Taken: 202 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6971
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 30 Visual Saved: epoch_030.png
#   📦 NIfTI Saved: epoch_030_fake.nii.gz
# 💾 Saving checkpoints at epoch 30
#
# Start Epoch 31 / 200
# Epoch 31: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 31 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7362
#       ├─ G_Adversarial: 	 0.6964
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6944
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 31 Visual Saved: epoch_031.png
#   📦 NIfTI Saved: epoch_031_fake.nii.gz
#
# Start Epoch 32 / 200
# Epoch 32: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 32 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7369
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0402
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 32 Visual Saved: epoch_032.png
#   📦 NIfTI Saved: epoch_032_fake.nii.gz
#
# Start Epoch 33 / 200
# Epoch 33: 100%|████████████████| 479/479 [03:12<00:00,  2.48batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 33 / 200 	 Time Taken: 193 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7367
#       ├─ G_Adversarial: 	 0.6962
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 33 Visual Saved: epoch_033.png
#   📦 NIfTI Saved: epoch_033_fake.nii.gz
#
# Start Epoch 34 / 200
# Epoch 34: 100%|████████████████| 479/479 [03:18<00:00,  2.41batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 34 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 34 Visual Saved: epoch_034.png
#   📦 NIfTI Saved: epoch_034_fake.nii.gz
#
# Start Epoch 35 / 200
# Epoch 35: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.040]
# --------------------------------------------------------------------------------
# END OF EPOCH 35 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7377
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 35 Visual Saved: epoch_035.png
#   📦 NIfTI Saved: epoch_035_fake.nii.gz
# 💾 Saving checkpoints at epoch 35
#
# Start Epoch 36 / 200
# Epoch 36: 100%|████████████████| 479/479 [03:16<00:00,  2.43batch/s, G_L2=0.046]
# --------------------------------------------------------------------------------
# END OF EPOCH 36 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6958
#       └─ G_Pixelwise (L2): 	 0.0407
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 36 Visual Saved: epoch_036.png
#   📦 NIfTI Saved: epoch_036_fake.nii.gz
#
# Start Epoch 37 / 200
# Epoch 37: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.054]
# --------------------------------------------------------------------------------
# END OF EPOCH 37 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 37 Visual Saved: epoch_037.png
#   📦 NIfTI Saved: epoch_037_fake.nii.gz
#
# Start Epoch 38 / 200
# Epoch 38: 100%|████████████████| 479/479 [03:19<00:00,  2.41batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 38 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 38 Visual Saved: epoch_038.png
#   📦 NIfTI Saved: epoch_038_fake.nii.gz
#
# Start Epoch 39 / 200
# Epoch 39: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.024]
# --------------------------------------------------------------------------------
# END OF EPOCH 39 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0412
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 39 Visual Saved: epoch_039.png
#   📦 NIfTI Saved: epoch_039_fake.nii.gz
#
# Start Epoch 40 / 200
# Epoch 40: 100%|████████████████| 479/479 [03:08<00:00,  2.54batch/s, G_L2=0.072]
# --------------------------------------------------------------------------------
# END OF EPOCH 40 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 40 Visual Saved: epoch_040.png
#   📦 NIfTI Saved: epoch_040_fake.nii.gz
# 💾 Saving checkpoints at epoch 40
#
# Start Epoch 41 / 200
# Epoch 41: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 41 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 41 Visual Saved: epoch_041.png
#   📦 NIfTI Saved: epoch_041_fake.nii.gz
#
# Start Epoch 42 / 200
# Epoch 42: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 42 / 200 	 Time Taken: 192 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7374
#       ├─ G_Adversarial: 	 0.6962
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 42 Visual Saved: epoch_042.png
#   📦 NIfTI Saved: epoch_042_fake.nii.gz
#
# Start Epoch 43 / 200
# Epoch 43: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 43 / 200 	 Time Taken: 192 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7378
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 43 Visual Saved: epoch_043.png
#   📦 NIfTI Saved: epoch_043_fake.nii.gz
#
# Start Epoch 44 / 200
# Epoch 44: 100%|████████████████| 479/479 [03:17<00:00,  2.43batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 44 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6963
#       └─ G_Pixelwise (L2): 	 0.0407
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 44 Visual Saved: epoch_044.png
#   📦 NIfTI Saved: epoch_044_fake.nii.gz
#
# Start Epoch 45 / 200
# Epoch 45: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.036]
# --------------------------------------------------------------------------------
# END OF EPOCH 45 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7371
#       ├─ G_Adversarial: 	 0.6964
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6944
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 45 Visual Saved: epoch_045.png
#   📦 NIfTI Saved: epoch_045_fake.nii.gz
# 💾 Saving checkpoints at epoch 45
#
# Start Epoch 46 / 200
# Epoch 46: 100%|████████████████| 479/479 [03:18<00:00,  2.41batch/s, G_L2=0.029]
# --------------------------------------------------------------------------------
# END OF EPOCH 46 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7364
#       ├─ G_Adversarial: 	 0.6961
#       └─ G_Pixelwise (L2): 	 0.0403
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 46 Visual Saved: epoch_046.png
#   📦 NIfTI Saved: epoch_046_fake.nii.gz
#
# Start Epoch 47 / 200
# Epoch 47: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.041]
# --------------------------------------------------------------------------------
# END OF EPOCH 47 / 200 	 Time Taken: 193 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7360
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 47 Visual Saved: epoch_047.png
#   📦 NIfTI Saved: epoch_047_fake.nii.gz
#
# Start Epoch 48 / 200
# Epoch 48: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 48 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7359
#       ├─ G_Adversarial: 	 0.6961
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6940
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 48 Visual Saved: epoch_048.png
#   📦 NIfTI Saved: epoch_048_fake.nii.gz
#
# Start Epoch 49 / 200
# Epoch 49: 100%|████████████████| 479/479 [03:14<00:00,  2.46batch/s, G_L2=0.014]
# --------------------------------------------------------------------------------
# END OF EPOCH 49 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 49 Visual Saved: epoch_049.png
#   📦 NIfTI Saved: epoch_049_fake.nii.gz
#
# Start Epoch 50 / 200
# Epoch 50: 100%|████████████████| 479/479 [03:07<00:00,  2.55batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 50 / 200 	 Time Taken: 188 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7371
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 50 Visual Saved: epoch_050.png
#   📦 NIfTI Saved: epoch_050_fake.nii.gz
# 💾 Saving checkpoints at epoch 50
#
# Start Epoch 51 / 200
# Epoch 51: 100%|████████████████| 479/479 [03:17<00:00,  2.42batch/s, G_L2=0.018]
# --------------------------------------------------------------------------------
# END OF EPOCH 51 / 200 	 Time Taken: 198 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7357
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6937
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 51 Visual Saved: epoch_051.png
#   📦 NIfTI Saved: epoch_051_fake.nii.gz
#
# Start Epoch 52 / 200
# Epoch 52: 100%|████████████████| 479/479 [03:22<00:00,  2.36batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 52 / 200 	 Time Taken: 203 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7358
#       ├─ G_Adversarial: 	 0.6958
#       └─ G_Pixelwise (L2): 	 0.0400
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 52 Visual Saved: epoch_052.png
#   📦 NIfTI Saved: epoch_052_fake.nii.gz
#
# Start Epoch 53 / 200
# Epoch 53: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.044]
# --------------------------------------------------------------------------------
# END OF EPOCH 53 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7358
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 53 Visual Saved: epoch_053.png
#   📦 NIfTI Saved: epoch_053_fake.nii.gz
#
# Start Epoch 54 / 200
# Epoch 54: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.075]
# --------------------------------------------------------------------------------
# END OF EPOCH 54 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0409
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 54 Visual Saved: epoch_054.png
#   📦 NIfTI Saved: epoch_054_fake.nii.gz
#
# Start Epoch 55 / 200
# Epoch 55: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 55 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7360
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 55 Visual Saved: epoch_055.png
#   📦 NIfTI Saved: epoch_055_fake.nii.gz
# 💾 Saving checkpoints at epoch 55
#
# Start Epoch 56 / 200
# Epoch 56: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 56 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7354
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 56 Visual Saved: epoch_056.png
#   📦 NIfTI Saved: epoch_056_fake.nii.gz
#
# Start Epoch 57 / 200
# Epoch 57: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.065]
# --------------------------------------------------------------------------------
# END OF EPOCH 57 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7355
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 57 Visual Saved: epoch_057.png
#   📦 NIfTI Saved: epoch_057_fake.nii.gz
#
# Start Epoch 58 / 200
# Epoch 58: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.012]
# --------------------------------------------------------------------------------
# END OF EPOCH 58 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7352
#       ├─ G_Adversarial: 	 0.6957
#       └─ G_Pixelwise (L2): 	 0.0396
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 58 Visual Saved: epoch_058.png
#   📦 NIfTI Saved: epoch_058_fake.nii.gz
#
# Start Epoch 59 / 200
# Epoch 59: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 59 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7348
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0393
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 59 Visual Saved: epoch_059.png
#   📦 NIfTI Saved: epoch_059_fake.nii.gz
#
# Start Epoch 60 / 200
# Epoch 60: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.054]
# --------------------------------------------------------------------------------
# END OF EPOCH 60 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7348
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0393
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 60 Visual Saved: epoch_060.png
#   📦 NIfTI Saved: epoch_060_fake.nii.gz
# 💾 Saving checkpoints at epoch 60
#
# Start Epoch 61 / 200
# Epoch 61: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 61 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7353
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 61 Visual Saved: epoch_061.png
#   📦 NIfTI Saved: epoch_061_fake.nii.gz
#
# Start Epoch 62 / 200
# Epoch 62: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 62 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7356
#       ├─ G_Adversarial: 	 0.6957
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 62 Visual Saved: epoch_062.png
#   📦 NIfTI Saved: epoch_062_fake.nii.gz
#
# Start Epoch 63 / 200
# Epoch 63: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 63 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7350
#       ├─ G_Adversarial: 	 0.6954
#       └─ G_Pixelwise (L2): 	 0.0396
#     Discriminator (D): 	 Total ≈ 0.6938
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 63 Visual Saved: epoch_063.png
#   📦 NIfTI Saved: epoch_063_fake.nii.gz
#
# Start Epoch 64 / 200
# Epoch 64: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.048]
# --------------------------------------------------------------------------------
# END OF EPOCH 64 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7347
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0391
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 64 Visual Saved: epoch_064.png
#   📦 NIfTI Saved: epoch_064_fake.nii.gz
#
# Start Epoch 65 / 200
# Epoch 65: 100%|████████████████| 479/479 [03:10<00:00,  2.51batch/s, G_L2=0.011]
# ...
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 177 Visual Saved: epoch_177.png
#   📦 NIfTI Saved: epoch_177_fake.nii.gz
#
# Start Epoch 178 / 200
# Epoch 178: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 178 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000455 | D_lr = 0.0000046
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7295
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0356
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 178 Visual Saved: epoch_178.png
#   📦 NIfTI Saved: epoch_178_fake.nii.gz
#
# Start Epoch 179 / 200
# Epoch 179: 100%|███████████████| 479/479 [03:07<00:00,  2.56batch/s, G_L2=0.006]
# --------------------------------------------------------------------------------
# END OF EPOCH 179 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000436 | D_lr = 0.0000044
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7290
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 179 Visual Saved: epoch_179.png
#   📦 NIfTI Saved: epoch_179_fake.nii.gz
#
# Start Epoch 180 / 200
# Epoch 180: 100%|███████████████| 479/479 [03:06<00:00,  2.56batch/s, G_L2=0.040]
# --------------------------------------------------------------------------------
# END OF EPOCH 180 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000416 | D_lr = 0.0000042
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7296
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0358
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 180 Visual Saved: epoch_180.png
#   📦 NIfTI Saved: epoch_180_fake.nii.gz
# 💾 Saving checkpoints at epoch 180
#
# Start Epoch 181 / 200
# Epoch 181: 100%|███████████████| 479/479 [03:05<00:00,  2.59batch/s, G_L2=0.028]
# --------------------------------------------------------------------------------
# END OF EPOCH 181 / 200 	 Time Taken: 185 sec
#   Learning Rates: 	 G_lr = 0.0000396 | D_lr = 0.0000040
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7291
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 181 Visual Saved: epoch_181.png
#   📦 NIfTI Saved: epoch_181_fake.nii.gz
#
# Start Epoch 182 / 200
# Epoch 182: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 182 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000376 | D_lr = 0.0000038
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7293
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 182 Visual Saved: epoch_182.png
#   📦 NIfTI Saved: epoch_182_fake.nii.gz
#
# Start Epoch 183 / 200
# Epoch 183: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.033]
# --------------------------------------------------------------------------------
# END OF EPOCH 183 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000356 | D_lr = 0.0000036
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7296
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0356
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 183 Visual Saved: epoch_183.png
#   📦 NIfTI Saved: epoch_183_fake.nii.gz
#
# Start Epoch 184 / 200
# Epoch 184: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.031]
# --------------------------------------------------------------------------------
# END OF EPOCH 184 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000337 | D_lr = 0.0000034
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7290
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 184 Visual Saved: epoch_184.png
#   📦 NIfTI Saved: epoch_184_fake.nii.gz
#
# Start Epoch 185 / 200
# Epoch 185: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 185 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000317 | D_lr = 0.0000032
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0351
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 185 Visual Saved: epoch_185.png
#   📦 NIfTI Saved: epoch_185_fake.nii.gz
# 💾 Saving checkpoints at epoch 185
#
# Start Epoch 186 / 200
# Epoch 186: 100%|███████████████| 479/479 [03:06<00:00,  2.56batch/s, G_L2=0.033]
# --------------------------------------------------------------------------------
# END OF EPOCH 186 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000297 | D_lr = 0.0000030
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0351
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 186 Visual Saved: epoch_186.png
#   📦 NIfTI Saved: epoch_186_fake.nii.gz
#
# Start Epoch 187 / 200
# Epoch 187: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 187 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000277 | D_lr = 0.0000028
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 187 Visual Saved: epoch_187.png
#   📦 NIfTI Saved: epoch_187_fake.nii.gz
#
# Start Epoch 188 / 200
# Epoch 188: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 188 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000257 | D_lr = 0.0000026
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7293
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0354
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 188 Visual Saved: epoch_188.png
#   📦 NIfTI Saved: epoch_188_fake.nii.gz
#
# Start Epoch 189 / 200
# Epoch 189: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 189 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000238 | D_lr = 0.0000024
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7285
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 189 Visual Saved: epoch_189.png
#   📦 NIfTI Saved: epoch_189_fake.nii.gz
#
# Start Epoch 190 / 200
# Epoch 190: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.008]
# --------------------------------------------------------------------------------
# END OF EPOCH 190 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000218 | D_lr = 0.0000022
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7285
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 190 Visual Saved: epoch_190.png
#   📦 NIfTI Saved: epoch_190_fake.nii.gz
# 💾 Saving checkpoints at epoch 190
#
# Start Epoch 191 / 200
# Epoch 191: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.020]
# --------------------------------------------------------------------------------
# END OF EPOCH 191 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000198 | D_lr = 0.0000020
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7288
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0352
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6931
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 191 Visual Saved: epoch_191.png
#   📦 NIfTI Saved: epoch_191_fake.nii.gz
#
# Start Epoch 192 / 200
# Epoch 192: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 192 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000178 | D_lr = 0.0000018
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7287
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 192 Visual Saved: epoch_192.png
#   📦 NIfTI Saved: epoch_192_fake.nii.gz
#
# Start Epoch 193 / 200
# Epoch 193: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.061]
# --------------------------------------------------------------------------------
# END OF EPOCH 193 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000158 | D_lr = 0.0000016
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 193 Visual Saved: epoch_193.png
#   📦 NIfTI Saved: epoch_193_fake.nii.gz
#
# Start Epoch 194 / 200
# Epoch 194: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.071]
# --------------------------------------------------------------------------------
# END OF EPOCH 194 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000139 | D_lr = 0.0000014
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7287
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0350
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 194 Visual Saved: epoch_194.png
#   📦 NIfTI Saved: epoch_194_fake.nii.gz
#
# Start Epoch 195 / 200
# Epoch 195: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.028]
# --------------------------------------------------------------------------------
# END OF EPOCH 195 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000119 | D_lr = 0.0000012
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 195 Visual Saved: epoch_195.png
#   📦 NIfTI Saved: epoch_195_fake.nii.gz
# 💾 Saving checkpoints at epoch 195
#
# Start Epoch 196 / 200
# Epoch 196: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 196 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000099 | D_lr = 0.0000010
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7282
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0346
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 196 Visual Saved: epoch_196.png
#   📦 NIfTI Saved: epoch_196_fake.nii.gz
#
# Start Epoch 197 / 200
# Epoch 197: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.068]
# --------------------------------------------------------------------------------
# END OF EPOCH 197 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000079 | D_lr = 0.0000008
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6928
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 197 Visual Saved: epoch_197.png
#   📦 NIfTI Saved: epoch_197_fake.nii.gz
#
# Start Epoch 198 / 200
# Epoch 198: 100%|███████████████| 479/479 [03:05<00:00,  2.58batch/s, G_L2=0.019]
# --------------------------------------------------------------------------------
# END OF EPOCH 198 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000059 | D_lr = 0.0000006
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0350
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 198 Visual Saved: epoch_198.png
#   📦 NIfTI Saved: epoch_198_fake.nii.gz
#
# Start Epoch 199 / 200
# Epoch 199: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.024]
# --------------------------------------------------------------------------------
# END OF EPOCH 199 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000040 | D_lr = 0.0000004
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7281
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0346
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 199 Visual Saved: epoch_199.png
#   📦 NIfTI Saved: epoch_199_fake.nii.gz
#
# Start Epoch 200 / 200
# Epoch 200: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.047]
# --------------------------------------------------------------------------------
# END OF EPOCH 200 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000020 | D_lr = 0.0000002
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0352
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 200 Visual Saved: epoch_200.png
#   📦 NIfTI Saved: epoch_200_fake.nii.gz
# 💾 Saving checkpoints at epoch 200
# 🎉 Training Finished!

# %%
# 运行训练脚本
# 注意：感叹号 ! 表示调用系统终端执行命令
# !{cmd}
# Out:
# Dataset [UltrasoundDataset] created. Size: 959, Batch Size: 2, Shuffle: True, Workers: 16
# initialize network with normal
# initialize network with normal
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 116.932 M
# [Network D] Total number of parameters : 11.052 M
# -----------------------------------------------
# ----------------------------------------------------------------
# ----------------- Options ---------------
#                batch_size: 2
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: /mnt/g/1024                   	[default: ./project_assets/Ultrasound_Simulation_Data_500_2/04_Pair_data_1024]
#              display_freq: 100
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: [0]                           	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_L2: 1.0                           	[default: 100.0]
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 0.1                           	[default: 1.0]
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: run_03_z1024_baseline_alldata 	[default: experiment_augan]
#                       ndf: 64
#                      netD: pixel
#                      netG: unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                      norm: instance
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_workers: 16                            	[default: 4]
#                 output_nc: 1
#              patch_size_d: 256
#              patch_size_h: 64
#              patch_size_w: 64
#                     phase: train
#                print_freq: 20
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 1000
#                 spacing_x: 0.2
#                 spacing_z: 0.0362
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
#                          🚀 AUGAN TRAINING CONFIGURATION
# ================================================================================
#   - Device:        cuda:0
#   - Data Root:     /mnt/g/1024
#   - Dataset Size:  479 volumes
#   - Batch Size:    2
#   - Patch Size:    [D=256, H=64, W=64]
#   - Physics:       Z_spacing=0.0362mm, X_spacing=0.2mm
#   - Visual Aspect: 0.1810 (Image will be vertically compressed)
#   - Model:         G=unet_3d, D=pixel
#   - LR Config:     G=0.0002, D=2e-05
#   - L2 Weight:     1.0
#   - Augmentation:  No Flip, No Elastic
# ================================================================================
#
# 📸 Saving initial sample (Step 0 check)...
#   🖼️  Epoch 0 Visual Saved: epoch_000.png
#   📦 NIfTI Saved: epoch_000_fake.nii.gz
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█████████████████| 479/479 [03:38<00:00,  2.19batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 219 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7604
#       ├─ G_Adversarial: 	 0.6316
#       └─ G_Pixelwise (L2): 	 0.1288
#     Discriminator (D): 	 Total ≈ 0.9621
#       ├─ D_Real_Loss: 	 0.9253
#       └─ D_Fake_Loss: 	 0.9990
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 1 Visual Saved: epoch_001.png
#   📦 NIfTI Saved: epoch_001_fake.nii.gz
#
# Start Epoch 2 / 200
# Epoch 2: 100%|█████████████████| 479/479 [03:38<00:00,  2.19batch/s, G_L2=0.082]
# --------------------------------------------------------------------------------
# END OF EPOCH 2 / 200 	 Time Taken: 219 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7522
#       ├─ G_Adversarial: 	 0.6857
#       └─ G_Pixelwise (L2): 	 0.0665
#     Discriminator (D): 	 Total ≈ 0.7295
#       ├─ D_Real_Loss: 	 0.7304
#       └─ D_Fake_Loss: 	 0.7286
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 2 Visual Saved: epoch_002.png
#   📦 NIfTI Saved: epoch_002_fake.nii.gz
#
# Start Epoch 3 / 200
# Epoch 3: 100%|█████████████████| 479/479 [03:34<00:00,  2.23batch/s, G_L2=0.095]
# --------------------------------------------------------------------------------
# END OF EPOCH 3 / 200 	 Time Taken: 215 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7536
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0555
#     Discriminator (D): 	 Total ≈ 0.7095
#       ├─ D_Real_Loss: 	 0.7097
#       └─ D_Fake_Loss: 	 0.7093
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 3 Visual Saved: epoch_003.png
#   📦 NIfTI Saved: epoch_003_fake.nii.gz
#
# Start Epoch 4 / 200
# Epoch 4: 100%|█████████████████| 479/479 [03:31<00:00,  2.26batch/s, G_L2=0.004]
# --------------------------------------------------------------------------------
# END OF EPOCH 4 / 200 	 Time Taken: 212 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7543
#       ├─ G_Adversarial: 	 0.7028
#       └─ G_Pixelwise (L2): 	 0.0515
#     Discriminator (D): 	 Total ≈ 0.7033
#       ├─ D_Real_Loss: 	 0.7037
#       └─ D_Fake_Loss: 	 0.7030
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 4 Visual Saved: epoch_004.png
#   📦 NIfTI Saved: epoch_004_fake.nii.gz
#
# Start Epoch 5 / 200
# Epoch 5: 100%|█████████████████| 479/479 [03:31<00:00,  2.26batch/s, G_L2=0.055]
# --------------------------------------------------------------------------------
# END OF EPOCH 5 / 200 	 Time Taken: 212 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7539
#       ├─ G_Adversarial: 	 0.7041
#       └─ G_Pixelwise (L2): 	 0.0497
#     Discriminator (D): 	 Total ≈ 0.7021
#       ├─ D_Real_Loss: 	 0.7029
#       └─ D_Fake_Loss: 	 0.7013
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 5 Visual Saved: epoch_005.png
#   📦 NIfTI Saved: epoch_005_fake.nii.gz
# 💾 Saving checkpoints at epoch 5
#
# Start Epoch 6 / 200
# Epoch 6: 100%|█████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.050]
# --------------------------------------------------------------------------------
# END OF EPOCH 6 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7514
#       ├─ G_Adversarial: 	 0.7024
#       └─ G_Pixelwise (L2): 	 0.0489
#     Discriminator (D): 	 Total ≈ 0.6995
#       ├─ D_Real_Loss: 	 0.6992
#       └─ D_Fake_Loss: 	 0.6997
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 6 Visual Saved: epoch_006.png
#   📦 NIfTI Saved: epoch_006_fake.nii.gz
#
# Start Epoch 7 / 200
# Epoch 7: 100%|█████████████████| 479/479 [03:16<00:00,  2.43batch/s, G_L2=0.016]
# --------------------------------------------------------------------------------
# END OF EPOCH 7 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7515
#       ├─ G_Adversarial: 	 0.7037
#       └─ G_Pixelwise (L2): 	 0.0478
#     Discriminator (D): 	 Total ≈ 0.6984
#       ├─ D_Real_Loss: 	 0.6990
#       └─ D_Fake_Loss: 	 0.6978
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 7 Visual Saved: epoch_007.png
#   📦 NIfTI Saved: epoch_007_fake.nii.gz
#
# Start Epoch 8 / 200
# Epoch 8: 100%|█████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.072]
# --------------------------------------------------------------------------------
# END OF EPOCH 8 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7514
#       ├─ G_Adversarial: 	 0.7041
#       └─ G_Pixelwise (L2): 	 0.0474
#     Discriminator (D): 	 Total ≈ 0.6977
#       ├─ D_Real_Loss: 	 0.6977
#       └─ D_Fake_Loss: 	 0.6978
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 8 Visual Saved: epoch_008.png
#   📦 NIfTI Saved: epoch_008_fake.nii.gz
#
# Start Epoch 9 / 200
# Epoch 9: 100%|█████████████████| 479/479 [03:15<00:00,  2.45batch/s, G_L2=0.045]
# --------------------------------------------------------------------------------
# END OF EPOCH 9 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7500
#       ├─ G_Adversarial: 	 0.7025
#       └─ G_Pixelwise (L2): 	 0.0474
#     Discriminator (D): 	 Total ≈ 0.6972
#       ├─ D_Real_Loss: 	 0.6973
#       └─ D_Fake_Loss: 	 0.6971
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 9 Visual Saved: epoch_009.png
#   📦 NIfTI Saved: epoch_009_fake.nii.gz
#
# Start Epoch 10 / 200
# Epoch 10: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 10 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7490
#       ├─ G_Adversarial: 	 0.7018
#       └─ G_Pixelwise (L2): 	 0.0472
#     Discriminator (D): 	 Total ≈ 0.6971
#       ├─ D_Real_Loss: 	 0.6973
#       └─ D_Fake_Loss: 	 0.6969
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 10 Visual Saved: epoch_010.png
#   📦 NIfTI Saved: epoch_010_fake.nii.gz
# 💾 Saving checkpoints at epoch 10
#
# Start Epoch 11 / 200
# Epoch 11: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 11 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7479
#       ├─ G_Adversarial: 	 0.7017
#       └─ G_Pixelwise (L2): 	 0.0463
#     Discriminator (D): 	 Total ≈ 0.6966
#       ├─ D_Real_Loss: 	 0.6967
#       └─ D_Fake_Loss: 	 0.6965
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 11 Visual Saved: epoch_011.png
#   📦 NIfTI Saved: epoch_011_fake.nii.gz
#
# Start Epoch 12 / 200
# Epoch 12: 100%|████████████████| 479/479 [03:15<00:00,  2.45batch/s, G_L2=0.031]
# --------------------------------------------------------------------------------
# END OF EPOCH 12 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7462
#       ├─ G_Adversarial: 	 0.7010
#       └─ G_Pixelwise (L2): 	 0.0452
#     Discriminator (D): 	 Total ≈ 0.6963
#       ├─ D_Real_Loss: 	 0.6967
#       └─ D_Fake_Loss: 	 0.6959
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 12 Visual Saved: epoch_012.png
#   📦 NIfTI Saved: epoch_012_fake.nii.gz
#
# Start Epoch 13 / 200
# Epoch 13: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.025]
# --------------------------------------------------------------------------------
# END OF EPOCH 13 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7473
#       ├─ G_Adversarial: 	 0.7019
#       └─ G_Pixelwise (L2): 	 0.0454
#     Discriminator (D): 	 Total ≈ 0.6966
#       ├─ D_Real_Loss: 	 0.6969
#       └─ D_Fake_Loss: 	 0.6963
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 13 Visual Saved: epoch_013.png
#   📦 NIfTI Saved: epoch_013_fake.nii.gz
#
# Start Epoch 14 / 200
# Epoch 14: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.036]
# --------------------------------------------------------------------------------
# END OF EPOCH 14 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7432
#       ├─ G_Adversarial: 	 0.6992
#       └─ G_Pixelwise (L2): 	 0.0439
#     Discriminator (D): 	 Total ≈ 0.6954
#       ├─ D_Real_Loss: 	 0.6955
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 14 Visual Saved: epoch_014.png
#   📦 NIfTI Saved: epoch_014_fake.nii.gz
#
# Start Epoch 15 / 200
# Epoch 15: 100%|████████████████| 479/479 [03:15<00:00,  2.46batch/s, G_L2=0.079]
# --------------------------------------------------------------------------------
# END OF EPOCH 15 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7445
#       ├─ G_Adversarial: 	 0.7000
#       └─ G_Pixelwise (L2): 	 0.0444
#     Discriminator (D): 	 Total ≈ 0.6957
#       ├─ D_Real_Loss: 	 0.6958
#       └─ D_Fake_Loss: 	 0.6956
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 15 Visual Saved: epoch_015.png
#   📦 NIfTI Saved: epoch_015_fake.nii.gz
# 💾 Saving checkpoints at epoch 15
#
# Start Epoch 16 / 200
# Epoch 16: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 16 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7423
#       ├─ G_Adversarial: 	 0.6994
#       └─ G_Pixelwise (L2): 	 0.0430
#     Discriminator (D): 	 Total ≈ 0.6955
#       ├─ D_Real_Loss: 	 0.6956
#       └─ D_Fake_Loss: 	 0.6954
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 16 Visual Saved: epoch_016.png
#   📦 NIfTI Saved: epoch_016_fake.nii.gz
#
# Start Epoch 17 / 200
# Epoch 17: 100%|████████████████| 479/479 [03:21<00:00,  2.38batch/s, G_L2=0.076]
# --------------------------------------------------------------------------------
# END OF EPOCH 17 / 200 	 Time Taken: 201 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7407
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0421
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6956
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 17 Visual Saved: epoch_017.png
#   📦 NIfTI Saved: epoch_017_fake.nii.gz
#
# Start Epoch 18 / 200
# Epoch 18: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 18 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7411
#       ├─ G_Adversarial: 	 0.6981
#       └─ G_Pixelwise (L2): 	 0.0429
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6953
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 18 Visual Saved: epoch_018.png
#   📦 NIfTI Saved: epoch_018_fake.nii.gz
#
# Start Epoch 19 / 200
# Epoch 19: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 19 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7408
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0422
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 19 Visual Saved: epoch_019.png
#   📦 NIfTI Saved: epoch_019_fake.nii.gz
#
# Start Epoch 20 / 200
# Epoch 20: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 20 / 200 	 Time Taken: 196 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7390
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0414
#     Discriminator (D): 	 Total ≈ 0.6952
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6952
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 20 Visual Saved: epoch_020.png
#   📦 NIfTI Saved: epoch_020_fake.nii.gz
# 💾 Saving checkpoints at epoch 20
#
# Start Epoch 21 / 200
# Epoch 21: 100%|████████████████| 479/479 [03:27<00:00,  2.31batch/s, G_L2=0.016]
# --------------------------------------------------------------------------------
# END OF EPOCH 21 / 200 	 Time Taken: 207 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7392
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0415
#     Discriminator (D): 	 Total ≈ 0.6949
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6947
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 21 Visual Saved: epoch_021.png
#   📦 NIfTI Saved: epoch_021_fake.nii.gz
#
# Start Epoch 22 / 200
# Epoch 22: 100%|████████████████| 479/479 [03:36<00:00,  2.22batch/s, G_L2=0.045]
# --------------------------------------------------------------------------------
# END OF EPOCH 22 / 200 	 Time Taken: 216 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7392
#       ├─ G_Adversarial: 	 0.6976
#       └─ G_Pixelwise (L2): 	 0.0416
#     Discriminator (D): 	 Total ≈ 0.6950
#       ├─ D_Real_Loss: 	 0.6952
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 22 Visual Saved: epoch_022.png
#   📦 NIfTI Saved: epoch_022_fake.nii.gz
#
# Start Epoch 23 / 200
# Epoch 23: 100%|████████████████| 479/479 [03:37<00:00,  2.20batch/s, G_L2=0.003]
# --------------------------------------------------------------------------------
# END OF EPOCH 23 / 200 	 Time Taken: 217 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7411
#       ├─ G_Adversarial: 	 0.6986
#       └─ G_Pixelwise (L2): 	 0.0425
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6951
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 23 Visual Saved: epoch_023.png
#   📦 NIfTI Saved: epoch_023_fake.nii.gz
#
# Start Epoch 24 / 200
# Epoch 24: 100%|████████████████| 479/479 [03:36<00:00,  2.21batch/s, G_L2=0.007]
# --------------------------------------------------------------------------------
# END OF EPOCH 24 / 200 	 Time Taken: 217 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7387
#       ├─ G_Adversarial: 	 0.6974
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6948
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6948
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 24 Visual Saved: epoch_024.png
#   📦 NIfTI Saved: epoch_024_fake.nii.gz
#
# Start Epoch 25 / 200
# Epoch 25: 100%|████████████████| 479/479 [03:34<00:00,  2.24batch/s, G_L2=0.025]
# --------------------------------------------------------------------------------
# END OF EPOCH 25 / 200 	 Time Taken: 214 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7379
#       ├─ G_Adversarial: 	 0.6972
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 25 Visual Saved: epoch_025.png
#   📦 NIfTI Saved: epoch_025_fake.nii.gz
# 💾 Saving checkpoints at epoch 25
#
# Start Epoch 26 / 200
# Epoch 26: 100%|████████████████| 479/479 [03:22<00:00,  2.36batch/s, G_L2=0.052]
# --------------------------------------------------------------------------------
# END OF EPOCH 26 / 200 	 Time Taken: 203 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7384
#       ├─ G_Adversarial: 	 0.6972
#       └─ G_Pixelwise (L2): 	 0.0412
#     Discriminator (D): 	 Total ≈ 0.6947
#       ├─ D_Real_Loss: 	 0.6950
#       └─ D_Fake_Loss: 	 0.6944
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 26 Visual Saved: epoch_026.png
#   📦 NIfTI Saved: epoch_026_fake.nii.gz
#
# Start Epoch 27 / 200
# Epoch 27: 100%|████████████████| 479/479 [03:24<00:00,  2.34batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 27 / 200 	 Time Taken: 205 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7381
#       ├─ G_Adversarial: 	 0.6975
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6946
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 27 Visual Saved: epoch_027.png
#   📦 NIfTI Saved: epoch_027_fake.nii.gz
#
# Start Epoch 28 / 200
# Epoch 28: 100%|████████████████| 479/479 [03:20<00:00,  2.39batch/s, G_L2=0.011]
# --------------------------------------------------------------------------------
# END OF EPOCH 28 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7391
#       ├─ G_Adversarial: 	 0.6977
#       └─ G_Pixelwise (L2): 	 0.0414
#     Discriminator (D): 	 Total ≈ 0.6945
#       ├─ D_Real_Loss: 	 0.6948
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 28 Visual Saved: epoch_028.png
#   📦 NIfTI Saved: epoch_028_fake.nii.gz
#
# Start Epoch 29 / 200
# Epoch 29: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.013]
# --------------------------------------------------------------------------------
# END OF EPOCH 29 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6969
#       └─ G_Pixelwise (L2): 	 0.0403
#     Discriminator (D): 	 Total ≈ 0.6946
#       ├─ D_Real_Loss: 	 0.6949
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 29 Visual Saved: epoch_029.png
#   📦 NIfTI Saved: epoch_029_fake.nii.gz
#
# Start Epoch 30 / 200
# Epoch 30: 100%|████████████████| 479/479 [03:22<00:00,  2.37batch/s, G_L2=0.005]
# --------------------------------------------------------------------------------
# END OF EPOCH 30 / 200 	 Time Taken: 202 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6971
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 30 Visual Saved: epoch_030.png
#   📦 NIfTI Saved: epoch_030_fake.nii.gz
# 💾 Saving checkpoints at epoch 30
#
# Start Epoch 31 / 200
# Epoch 31: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.049]
# --------------------------------------------------------------------------------
# END OF EPOCH 31 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7362
#       ├─ G_Adversarial: 	 0.6964
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6944
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 31 Visual Saved: epoch_031.png
#   📦 NIfTI Saved: epoch_031_fake.nii.gz
#
# Start Epoch 32 / 200
# Epoch 32: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 32 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7369
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0402
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6946
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 32 Visual Saved: epoch_032.png
#   📦 NIfTI Saved: epoch_032_fake.nii.gz
#
# Start Epoch 33 / 200
# Epoch 33: 100%|████████████████| 479/479 [03:12<00:00,  2.48batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 33 / 200 	 Time Taken: 193 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7367
#       ├─ G_Adversarial: 	 0.6962
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 33 Visual Saved: epoch_033.png
#   📦 NIfTI Saved: epoch_033_fake.nii.gz
#
# Start Epoch 34 / 200
# Epoch 34: 100%|████████████████| 479/479 [03:18<00:00,  2.41batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 34 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6944
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6945
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 34 Visual Saved: epoch_034.png
#   📦 NIfTI Saved: epoch_034_fake.nii.gz
#
# Start Epoch 35 / 200
# Epoch 35: 100%|████████████████| 479/479 [03:16<00:00,  2.44batch/s, G_L2=0.040]
# --------------------------------------------------------------------------------
# END OF EPOCH 35 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7377
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6943
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 35 Visual Saved: epoch_035.png
#   📦 NIfTI Saved: epoch_035_fake.nii.gz
# 💾 Saving checkpoints at epoch 35
#
# Start Epoch 36 / 200
# Epoch 36: 100%|████████████████| 479/479 [03:16<00:00,  2.43batch/s, G_L2=0.046]
# --------------------------------------------------------------------------------
# END OF EPOCH 36 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6958
#       └─ G_Pixelwise (L2): 	 0.0407
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 36 Visual Saved: epoch_036.png
#   📦 NIfTI Saved: epoch_036_fake.nii.gz
#
# Start Epoch 37 / 200
# Epoch 37: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.054]
# --------------------------------------------------------------------------------
# END OF EPOCH 37 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6967
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 37 Visual Saved: epoch_037.png
#   📦 NIfTI Saved: epoch_037_fake.nii.gz
#
# Start Epoch 38 / 200
# Epoch 38: 100%|████████████████| 479/479 [03:19<00:00,  2.41batch/s, G_L2=0.060]
# --------------------------------------------------------------------------------
# END OF EPOCH 38 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 38 Visual Saved: epoch_038.png
#   📦 NIfTI Saved: epoch_038_fake.nii.gz
#
# Start Epoch 39 / 200
# Epoch 39: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.024]
# --------------------------------------------------------------------------------
# END OF EPOCH 39 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7376
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0412
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 39 Visual Saved: epoch_039.png
#   📦 NIfTI Saved: epoch_039_fake.nii.gz
#
# Start Epoch 40 / 200
# Epoch 40: 100%|████████████████| 479/479 [03:08<00:00,  2.54batch/s, G_L2=0.072]
# --------------------------------------------------------------------------------
# END OF EPOCH 40 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0410
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 40 Visual Saved: epoch_040.png
#   📦 NIfTI Saved: epoch_040_fake.nii.gz
# 💾 Saving checkpoints at epoch 40
#
# Start Epoch 41 / 200
# Epoch 41: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 41 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7372
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 41 Visual Saved: epoch_041.png
#   📦 NIfTI Saved: epoch_041_fake.nii.gz
#
# Start Epoch 42 / 200
# Epoch 42: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 42 / 200 	 Time Taken: 192 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7374
#       ├─ G_Adversarial: 	 0.6962
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 42 Visual Saved: epoch_042.png
#   📦 NIfTI Saved: epoch_042_fake.nii.gz
#
# Start Epoch 43 / 200
# Epoch 43: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 43 / 200 	 Time Taken: 192 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7378
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0413
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 43 Visual Saved: epoch_043.png
#   📦 NIfTI Saved: epoch_043_fake.nii.gz
#
# Start Epoch 44 / 200
# Epoch 44: 100%|████████████████| 479/479 [03:17<00:00,  2.43batch/s, G_L2=0.066]
# --------------------------------------------------------------------------------
# END OF EPOCH 44 / 200 	 Time Taken: 197 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7370
#       ├─ G_Adversarial: 	 0.6963
#       └─ G_Pixelwise (L2): 	 0.0407
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 44 Visual Saved: epoch_044.png
#   📦 NIfTI Saved: epoch_044_fake.nii.gz
#
# Start Epoch 45 / 200
# Epoch 45: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.036]
# --------------------------------------------------------------------------------
# END OF EPOCH 45 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7371
#       ├─ G_Adversarial: 	 0.6964
#       └─ G_Pixelwise (L2): 	 0.0408
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6944
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 45 Visual Saved: epoch_045.png
#   📦 NIfTI Saved: epoch_045_fake.nii.gz
# 💾 Saving checkpoints at epoch 45
#
# Start Epoch 46 / 200
# Epoch 46: 100%|████████████████| 479/479 [03:18<00:00,  2.41batch/s, G_L2=0.029]
# --------------------------------------------------------------------------------
# END OF EPOCH 46 / 200 	 Time Taken: 199 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7364
#       ├─ G_Adversarial: 	 0.6961
#       └─ G_Pixelwise (L2): 	 0.0403
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 46 Visual Saved: epoch_046.png
#   📦 NIfTI Saved: epoch_046_fake.nii.gz
#
# Start Epoch 47 / 200
# Epoch 47: 100%|████████████████| 479/479 [03:12<00:00,  2.49batch/s, G_L2=0.041]
# --------------------------------------------------------------------------------
# END OF EPOCH 47 / 200 	 Time Taken: 193 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7360
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 47 Visual Saved: epoch_047.png
#   📦 NIfTI Saved: epoch_047_fake.nii.gz
#
# Start Epoch 48 / 200
# Epoch 48: 100%|████████████████| 479/479 [03:19<00:00,  2.40batch/s, G_L2=0.037]
# --------------------------------------------------------------------------------
# END OF EPOCH 48 / 200 	 Time Taken: 200 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7359
#       ├─ G_Adversarial: 	 0.6961
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6940
#       └─ D_Fake_Loss: 	 0.6942
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 48 Visual Saved: epoch_048.png
#   📦 NIfTI Saved: epoch_048_fake.nii.gz
#
# Start Epoch 49 / 200
# Epoch 49: 100%|████████████████| 479/479 [03:14<00:00,  2.46batch/s, G_L2=0.014]
# --------------------------------------------------------------------------------
# END OF EPOCH 49 / 200 	 Time Taken: 195 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6960
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 49 Visual Saved: epoch_049.png
#   📦 NIfTI Saved: epoch_049_fake.nii.gz
#
# Start Epoch 50 / 200
# Epoch 50: 100%|████████████████| 479/479 [03:07<00:00,  2.55batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 50 / 200 	 Time Taken: 188 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7371
#       ├─ G_Adversarial: 	 0.6965
#       └─ G_Pixelwise (L2): 	 0.0405
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6940
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 50 Visual Saved: epoch_050.png
#   📦 NIfTI Saved: epoch_050_fake.nii.gz
# 💾 Saving checkpoints at epoch 50
#
# Start Epoch 51 / 200
# Epoch 51: 100%|████████████████| 479/479 [03:17<00:00,  2.42batch/s, G_L2=0.018]
# --------------------------------------------------------------------------------
# END OF EPOCH 51 / 200 	 Time Taken: 198 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7357
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6937
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 51 Visual Saved: epoch_051.png
#   📦 NIfTI Saved: epoch_051_fake.nii.gz
#
# Start Epoch 52 / 200
# Epoch 52: 100%|████████████████| 479/479 [03:22<00:00,  2.36batch/s, G_L2=0.035]
# --------------------------------------------------------------------------------
# END OF EPOCH 52 / 200 	 Time Taken: 203 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7358
#       ├─ G_Adversarial: 	 0.6958
#       └─ G_Pixelwise (L2): 	 0.0400
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 52 Visual Saved: epoch_052.png
#   📦 NIfTI Saved: epoch_052_fake.nii.gz
#
# Start Epoch 53 / 200
# Epoch 53: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.044]
# --------------------------------------------------------------------------------
# END OF EPOCH 53 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7358
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6941
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 53 Visual Saved: epoch_053.png
#   📦 NIfTI Saved: epoch_053_fake.nii.gz
#
# Start Epoch 54 / 200
# Epoch 54: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.075]
# --------------------------------------------------------------------------------
# END OF EPOCH 54 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7365
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0409
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 54 Visual Saved: epoch_054.png
#   📦 NIfTI Saved: epoch_054_fake.nii.gz
#
# Start Epoch 55 / 200
# Epoch 55: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.057]
# --------------------------------------------------------------------------------
# END OF EPOCH 55 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7360
#       ├─ G_Adversarial: 	 0.6959
#       └─ G_Pixelwise (L2): 	 0.0401
#     Discriminator (D): 	 Total ≈ 0.6941
#       ├─ D_Real_Loss: 	 0.6943
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 55 Visual Saved: epoch_055.png
#   📦 NIfTI Saved: epoch_055_fake.nii.gz
# 💾 Saving checkpoints at epoch 55
#
# Start Epoch 56 / 200
# Epoch 56: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.064]
# --------------------------------------------------------------------------------
# END OF EPOCH 56 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7354
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 56 Visual Saved: epoch_056.png
#   📦 NIfTI Saved: epoch_056_fake.nii.gz
#
# Start Epoch 57 / 200
# Epoch 57: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.065]
# --------------------------------------------------------------------------------
# END OF EPOCH 57 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7355
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 57 Visual Saved: epoch_057.png
#   📦 NIfTI Saved: epoch_057_fake.nii.gz
#
# Start Epoch 58 / 200
# Epoch 58: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.012]
# --------------------------------------------------------------------------------
# END OF EPOCH 58 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7352
#       ├─ G_Adversarial: 	 0.6957
#       └─ G_Pixelwise (L2): 	 0.0396
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 58 Visual Saved: epoch_058.png
#   📦 NIfTI Saved: epoch_058_fake.nii.gz
#
# Start Epoch 59 / 200
# Epoch 59: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 59 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7348
#       ├─ G_Adversarial: 	 0.6956
#       └─ G_Pixelwise (L2): 	 0.0393
#     Discriminator (D): 	 Total ≈ 0.6940
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 59 Visual Saved: epoch_059.png
#   📦 NIfTI Saved: epoch_059_fake.nii.gz
#
# Start Epoch 60 / 200
# Epoch 60: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.054]
# --------------------------------------------------------------------------------
# END OF EPOCH 60 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7348
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0393
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6939
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 60 Visual Saved: epoch_060.png
#   📦 NIfTI Saved: epoch_060_fake.nii.gz
# 💾 Saving checkpoints at epoch 60
#
# Start Epoch 61 / 200
# Epoch 61: 100%|████████████████| 479/479 [03:09<00:00,  2.53batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 61 / 200 	 Time Taken: 189 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7353
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0398
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6939
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 61 Visual Saved: epoch_061.png
#   📦 NIfTI Saved: epoch_061_fake.nii.gz
#
# Start Epoch 62 / 200
# Epoch 62: 100%|████████████████| 479/479 [03:09<00:00,  2.52batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 62 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7356
#       ├─ G_Adversarial: 	 0.6957
#       └─ G_Pixelwise (L2): 	 0.0399
#     Discriminator (D): 	 Total ≈ 0.6942
#       ├─ D_Real_Loss: 	 0.6942
#       └─ D_Fake_Loss: 	 0.6943
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 62 Visual Saved: epoch_062.png
#   📦 NIfTI Saved: epoch_062_fake.nii.gz
#
# Start Epoch 63 / 200
# Epoch 63: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 63 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7350
#       ├─ G_Adversarial: 	 0.6954
#       └─ G_Pixelwise (L2): 	 0.0396
#     Discriminator (D): 	 Total ≈ 0.6938
#       ├─ D_Real_Loss: 	 0.6938
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 63 Visual Saved: epoch_063.png
#   📦 NIfTI Saved: epoch_063_fake.nii.gz
#
# Start Epoch 64 / 200
# Epoch 64: 100%|████████████████| 479/479 [03:10<00:00,  2.52batch/s, G_L2=0.048]
# --------------------------------------------------------------------------------
# END OF EPOCH 64 / 200 	 Time Taken: 190 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0000200
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7347
#       ├─ G_Adversarial: 	 0.6955
#       └─ G_Pixelwise (L2): 	 0.0391
#     Discriminator (D): 	 Total ≈ 0.6939
#       ├─ D_Real_Loss: 	 0.6941
#       └─ D_Fake_Loss: 	 0.6938
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 64 Visual Saved: epoch_064.png
#   📦 NIfTI Saved: epoch_064_fake.nii.gz
#
# Start Epoch 65 / 200
# Epoch 65: 100%|████████████████| 479/479 [03:10<00:00,  2.51batch/s, G_L2=0.011]
# ...
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 177 Visual Saved: epoch_177.png
#   📦 NIfTI Saved: epoch_177_fake.nii.gz
#
# Start Epoch 178 / 200
# Epoch 178: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.058]
# --------------------------------------------------------------------------------
# END OF EPOCH 178 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000455 | D_lr = 0.0000046
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7295
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0356
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 178 Visual Saved: epoch_178.png
#   📦 NIfTI Saved: epoch_178_fake.nii.gz
#
# Start Epoch 179 / 200
# Epoch 179: 100%|███████████████| 479/479 [03:07<00:00,  2.56batch/s, G_L2=0.006]
# --------------------------------------------------------------------------------
# END OF EPOCH 179 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000436 | D_lr = 0.0000044
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7290
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 179 Visual Saved: epoch_179.png
#   📦 NIfTI Saved: epoch_179_fake.nii.gz
#
# Start Epoch 180 / 200
# Epoch 180: 100%|███████████████| 479/479 [03:06<00:00,  2.56batch/s, G_L2=0.040]
# --------------------------------------------------------------------------------
# END OF EPOCH 180 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000416 | D_lr = 0.0000042
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7296
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0358
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 180 Visual Saved: epoch_180.png
#   📦 NIfTI Saved: epoch_180_fake.nii.gz
# 💾 Saving checkpoints at epoch 180
#
# Start Epoch 181 / 200
# Epoch 181: 100%|███████████████| 479/479 [03:05<00:00,  2.59batch/s, G_L2=0.028]
# --------------------------------------------------------------------------------
# END OF EPOCH 181 / 200 	 Time Taken: 185 sec
#   Learning Rates: 	 G_lr = 0.0000396 | D_lr = 0.0000040
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7291
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 181 Visual Saved: epoch_181.png
#   📦 NIfTI Saved: epoch_181_fake.nii.gz
#
# Start Epoch 182 / 200
# Epoch 182: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.062]
# --------------------------------------------------------------------------------
# END OF EPOCH 182 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000376 | D_lr = 0.0000038
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7293
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 182 Visual Saved: epoch_182.png
#   📦 NIfTI Saved: epoch_182_fake.nii.gz
#
# Start Epoch 183 / 200
# Epoch 183: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.033]
# --------------------------------------------------------------------------------
# END OF EPOCH 183 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000356 | D_lr = 0.0000036
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7296
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0356
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6935
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 183 Visual Saved: epoch_183.png
#   📦 NIfTI Saved: epoch_183_fake.nii.gz
#
# Start Epoch 184 / 200
# Epoch 184: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.031]
# --------------------------------------------------------------------------------
# END OF EPOCH 184 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000337 | D_lr = 0.0000034
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7290
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0353
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 184 Visual Saved: epoch_184.png
#   📦 NIfTI Saved: epoch_184_fake.nii.gz
#
# Start Epoch 185 / 200
# Epoch 185: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.030]
# --------------------------------------------------------------------------------
# END OF EPOCH 185 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000317 | D_lr = 0.0000032
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6939
#       └─ G_Pixelwise (L2): 	 0.0351
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 185 Visual Saved: epoch_185.png
#   📦 NIfTI Saved: epoch_185_fake.nii.gz
# 💾 Saving checkpoints at epoch 185
#
# Start Epoch 186 / 200
# Epoch 186: 100%|███████████████| 479/479 [03:06<00:00,  2.56batch/s, G_L2=0.033]
# --------------------------------------------------------------------------------
# END OF EPOCH 186 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000297 | D_lr = 0.0000030
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0351
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 186 Visual Saved: epoch_186.png
#   📦 NIfTI Saved: epoch_186_fake.nii.gz
#
# Start Epoch 187 / 200
# Epoch 187: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 187 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000277 | D_lr = 0.0000028
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 187 Visual Saved: epoch_187.png
#   📦 NIfTI Saved: epoch_187_fake.nii.gz
#
# Start Epoch 188 / 200
# Epoch 188: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.043]
# --------------------------------------------------------------------------------
# END OF EPOCH 188 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000257 | D_lr = 0.0000026
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7293
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0354
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 188 Visual Saved: epoch_188.png
#   📦 NIfTI Saved: epoch_188_fake.nii.gz
#
# Start Epoch 189 / 200
# Epoch 189: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.032]
# --------------------------------------------------------------------------------
# END OF EPOCH 189 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000238 | D_lr = 0.0000024
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7285
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 189 Visual Saved: epoch_189.png
#   📦 NIfTI Saved: epoch_189_fake.nii.gz
#
# Start Epoch 190 / 200
# Epoch 190: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.008]
# --------------------------------------------------------------------------------
# END OF EPOCH 190 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000218 | D_lr = 0.0000022
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7285
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 190 Visual Saved: epoch_190.png
#   📦 NIfTI Saved: epoch_190_fake.nii.gz
# 💾 Saving checkpoints at epoch 190
#
# Start Epoch 191 / 200
# Epoch 191: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.020]
# --------------------------------------------------------------------------------
# END OF EPOCH 191 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000198 | D_lr = 0.0000020
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7288
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0352
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6931
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 191 Visual Saved: epoch_191.png
#   📦 NIfTI Saved: epoch_191_fake.nii.gz
#
# Start Epoch 192 / 200
# Epoch 192: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.059]
# --------------------------------------------------------------------------------
# END OF EPOCH 192 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000178 | D_lr = 0.0000018
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7287
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 192 Visual Saved: epoch_192.png
#   📦 NIfTI Saved: epoch_192_fake.nii.gz
#
# Start Epoch 193 / 200
# Epoch 193: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.061]
# --------------------------------------------------------------------------------
# END OF EPOCH 193 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000158 | D_lr = 0.0000016
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 193 Visual Saved: epoch_193.png
#   📦 NIfTI Saved: epoch_193_fake.nii.gz
#
# Start Epoch 194 / 200
# Epoch 194: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.071]
# --------------------------------------------------------------------------------
# END OF EPOCH 194 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000139 | D_lr = 0.0000014
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7287
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0350
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 194 Visual Saved: epoch_194.png
#   📦 NIfTI Saved: epoch_194_fake.nii.gz
#
# Start Epoch 195 / 200
# Epoch 195: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.028]
# --------------------------------------------------------------------------------
# END OF EPOCH 195 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000119 | D_lr = 0.0000012
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0349
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 195 Visual Saved: epoch_195.png
#   📦 NIfTI Saved: epoch_195_fake.nii.gz
# 💾 Saving checkpoints at epoch 195
#
# Start Epoch 196 / 200
# Epoch 196: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.039]
# --------------------------------------------------------------------------------
# END OF EPOCH 196 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000099 | D_lr = 0.0000010
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7282
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0346
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 196 Visual Saved: epoch_196.png
#   📦 NIfTI Saved: epoch_196_fake.nii.gz
#
# Start Epoch 197 / 200
# Epoch 197: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.068]
# --------------------------------------------------------------------------------
# END OF EPOCH 197 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000079 | D_lr = 0.0000008
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6938
#       └─ G_Pixelwise (L2): 	 0.0348
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6934
#       └─ D_Fake_Loss: 	 0.6928
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 197 Visual Saved: epoch_197.png
#   📦 NIfTI Saved: epoch_197_fake.nii.gz
#
# Start Epoch 198 / 200
# Epoch 198: 100%|███████████████| 479/479 [03:05<00:00,  2.58batch/s, G_L2=0.019]
# --------------------------------------------------------------------------------
# END OF EPOCH 198 / 200 	 Time Taken: 186 sec
#   Learning Rates: 	 G_lr = 0.0000059 | D_lr = 0.0000006
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7286
#       ├─ G_Adversarial: 	 0.6936
#       └─ G_Pixelwise (L2): 	 0.0350
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6932
#       └─ D_Fake_Loss: 	 0.6930
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 198 Visual Saved: epoch_198.png
#   📦 NIfTI Saved: epoch_198_fake.nii.gz
#
# Start Epoch 199 / 200
# Epoch 199: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.024]
# --------------------------------------------------------------------------------
# END OF EPOCH 199 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000040 | D_lr = 0.0000004
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7281
#       ├─ G_Adversarial: 	 0.6935
#       └─ G_Pixelwise (L2): 	 0.0346
#     Discriminator (D): 	 Total ≈ 0.6932
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6931
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 199 Visual Saved: epoch_199.png
#   📦 NIfTI Saved: epoch_199_fake.nii.gz
#
# Start Epoch 200 / 200
# Epoch 200: 100%|███████████████| 479/479 [03:06<00:00,  2.57batch/s, G_L2=0.047]
# --------------------------------------------------------------------------------
# END OF EPOCH 200 / 200 	 Time Taken: 187 sec
#   Learning Rates: 	 G_lr = 0.0000020 | D_lr = 0.0000002
#   Average Losses:
#     Generator (G): 	 Total ≈ 0.7289
#       ├─ G_Adversarial: 	 0.6937
#       └─ G_Pixelwise (L2): 	 0.0352
#     Discriminator (D): 	 Total ≈ 0.6931
#       ├─ D_Real_Loss: 	 0.6933
#       └─ D_Fake_Loss: 	 0.6929
# --------------------------------------------------------------------------------
#
#   🖼️  Epoch 200 Visual Saved: epoch_200.png
#   📦 NIfTI Saved: epoch_200_fake.nii.gz
# 💾 Saving checkpoints at epoch 200
# 🎉 Training Finished!

# %%
# 查看最新的训练结果图 (可以反复运行此格)
show_latest_visuals(EXPERIMENT_NAME)
